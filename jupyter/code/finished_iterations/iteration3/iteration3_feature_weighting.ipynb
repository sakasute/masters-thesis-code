# %% [markdown]
# # Iteraatio 3 - kohteiden ominaisuuksien valintaa gini-indeksillä

# %%
import numpy as np
import pandas as pd

WORKING_DIRECTORY = '/mnt/c/git/masters-thesis-code/jupyter/code/'

# %% [markdown]
# ## Ladataan yritysdata

# %%
SELECTED_COMPANY_FEATURES = ['company_form_code', 'location_municipality_code', 
                             'location_region_code', 'company_status_code', 'industry_code', 'turnover', 
                             'net_profit', 'personnel_average', 'performer_ranking_points', 'risk_rating_class']

# %%
COMPANIES_DF = pd.read_pickle(WORKING_DIRECTORY + "data/pandas_pickles/prod_data_proto2.pkl")

# %%
ITEM_IDS = list(COMPANIES_DF['business_id'].unique())

# %% [markdown]
# ## Ladataa vuorovaikutusdata

# %%
interactions_tmp = pd \
    .read_csv(WORKING_DIRECTORY + 'data/interactions_2021_08_19.csv',
             delimiter='\t',
             dtype={
                 'group_id': 'string',
                 'business_id': 'string',
                 'owner': 'string'
             })

# otetaan pois 1 kokoiset ryhmät
group_sizes = interactions_tmp['group_id'].value_counts()
group_sizes_df = pd.DataFrame({'group_id': group_sizes.index, 'group_size': group_sizes.values})

INTERACTIONS_WITH_GROUP_SIZES_DF = interactions_tmp.merge(group_sizes_df, on='group_id')             
interactions_tmp = INTERACTIONS_WITH_GROUP_SIZES_DF[INTERACTIONS_WITH_GROUP_SIZES_DF.group_size >= 2]
#interactions_tmp = INTERACTIONS_WITH_GROUP_SIZES_DF[INTERACTIONS_WITH_GROUP_SIZES_DF.group_size <= 3000]
interactions_tmp.sort_values('group_size')
# Out:
#                                     group_id business_id  \
# 155696  3e9dd356-2b21-45ae-9ee4-7cd6cc122fe1    07577937
# 106198  31503959-943a-4081-abcc-dc80e5cb0402    15093748
# 313746  cab22fae-db47-46b6-b902-3d9a1b1051f6    01163004
# 313747  cab22fae-db47-46b6-b902-3d9a1b1051f6    10410900
# 545392  0967d6ed-88b7-4023-a720-f09f7051f24d    17944788
# ...                                      ...         ...
# 8042    a5c6ce2e-22ab-4871-bd72-e5da294b33cc    16029641
# 8043    a5c6ce2e-22ab-4871-bd72-e5da294b33cc    16030167
# 8044    a5c6ce2e-22ab-4871-bd72-e5da294b33cc    16030415
# 8031    a5c6ce2e-22ab-4871-bd72-e5da294b33cc    16001948
# 7025    a5c6ce2e-22ab-4871-bd72-e5da294b33cc    09710930
#
#                            owner  group_size
# 155696  5e87095492119e00066e7158           2
# 106198  5db034c64320cd0006d2b788           2
# 313746  5e4534bc7bf061000697e940           2
# 313747  5e4534bc7bf061000697e940           2
# 545392  5efdbc656488210007bc27f6           2
# ...                          ...         ...
# 8042    5e1489f3c2f568000654ecbb        3999
# 8043    5e1489f3c2f568000654ecbb        3999
# 8044    5e1489f3c2f568000654ecbb        3999
# 8031    5e1489f3c2f568000654ecbb        3999
# 7025    5e1489f3c2f568000654ecbb        3999
#
# [548107 rows x 4 columns]

# %%
# lisätään konserniyrityksille interaktiot
concern_interactions = interactions_tmp.copy()
concern_interactions['business_id'] = 'K-' + concern_interactions['business_id'].astype(str)
concern_interactions = concern_interactions[concern_interactions.business_id.isin(ITEM_IDS)]
concern_interactions
# Out:
#                                     group_id business_id  \
# 5       c2626398-faac-4ff3-b02d-cdc64b50cdaa  K-01681709
# 6       c2626398-faac-4ff3-b02d-cdc64b50cdaa  K-15055514
# 7       c2626398-faac-4ff3-b02d-cdc64b50cdaa  K-01876143
# 9       c2626398-faac-4ff3-b02d-cdc64b50cdaa  K-05363070
# 10      c2626398-faac-4ff3-b02d-cdc64b50cdaa  K-01387534
# ...                                      ...         ...
# 548074  8b0915ff-a0cb-4520-9160-8d783a6bf308  K-02106319
# 548110  8b0915ff-a0cb-4520-9160-8d783a6bf308  K-20333371
# 548137  8b0915ff-a0cb-4520-9160-8d783a6bf308  K-07027249
# 548162  8b0915ff-a0cb-4520-9160-8d783a6bf308  K-02011774
# 548171  8b0915ff-a0cb-4520-9160-8d783a6bf308  K-10459325
#
#                            owner  group_size
# 5       60646431ae18cb00063ed63f        1862
# 6       60646431ae18cb00063ed63f        1862
# 7       60646431ae18cb00063ed63f        1862
# 9       60646431ae18cb00063ed63f        1862
# 10      60646431ae18cb00063ed63f        1862
# ...                          ...         ...
# 548074  6110c56241e21e000857ca77         131
# 548110  6110c56241e21e000857ca77         131
# 548137  6110c56241e21e000857ca77         131
# 548162  6110c56241e21e000857ca77         131
# 548171  6110c56241e21e000857ca77         131
#
# [73277 rows x 4 columns]

# %%
# yhdistetään konserni-interaktiot tavallisiin ja poistetaan sellaiset interaktiot, joille ei löydy y-tunnusta
INTERACTIONS_DF = pd.concat([interactions_tmp, concern_interactions])
INTERACTIONS_DF = INTERACTIONS_DF[INTERACTIONS_DF.business_id.isin(ITEM_IDS)]
INTERACTIONS_DF[INTERACTIONS_DF['business_id'] == 'K-02011774']
# Out:
#                                     group_id business_id  \
# 18663   6c894b42-cbc6-4d18-8cf1-39ee91d2bf53  K-02011774
# 49204   66aea578-682d-45de-a200-77fa79a8c5e7  K-02011774
# 217786  608ac4ff-ab75-425b-a4f1-74d5defd43a3  K-02011774
# 231830  4d2c2290-72be-40fe-8506-42718d2aac25  K-02011774
# 254761  58f4cb31-0d40-42b2-9268-10d6dc64f1a0  K-02011774
# 298418  2177a613-3b16-483e-9c9b-dc20bd4225f6  K-02011774
# 354226  62c0017d-ff32-4584-8c85-562e9a1e8329  K-02011774
# 412123  3a44f374-56ee-4500-8829-c4b942b7afec  K-02011774
# 439385  725e7cd0-7031-4988-b4cb-69672c611514  K-02011774
# 451491  acfdacd6-0de0-4568-a819-c3c2e15ef221  K-02011774
# 459932  a18a99fb-bfb4-4c46-ad6d-89e7b74ff2c4  K-02011774
# 464050  51b071a7-bfc6-4add-93d2-11eea5346dc4  K-02011774
# 493257  ddaef9fe-0f14-45f9-b55f-8ad1532a8680  K-02011774
# 548162  8b0915ff-a0cb-4520-9160-8d783a6bf308  K-02011774
#
#                            owner  group_size
# 18663   6058a712ae18cb00063ed639        2175
# 49204   5db92c0ebc3e9100062ac0b0        3692
# 217786  5fbe6408f464de0006491d9e        1541
# 231830  5f5613da9769490006b0ebb3        3685
# 254761  5f5613da9769490006b0ebb3        2595
# 298418  608863795602580007e70ddf        3925
# 354226  5fab9e2dc07a1900066bab26        3949
# 412123  6033ae80484e8a0006fe437a        3966
# 439385  5db83a1cbc3e9100062ac0ab        1846
# 451491  6033ae80484e8a0006fe437a        3809
# 459932  60646431ae18cb00063ed63f        3143
# 464050  60646431ae18cb00063ed63f        2749
# 493257  60b5f4565735df0009ec7ea2        2235
# 548162  6110c56241e21e000857ca77         131

# %% [markdown]
# ## Poimitaan käytössä olevat ominaisuudet

# %%
features_tmp = [COMPANIES_DF[feature].unique() for feature in SELECTED_COMPANY_FEATURES]
FEATURES = [item for sublist in features_tmp for item in sublist]
len(FEATURES)
FEATURES
# Out:
# ['company_form_code+CO_26',
#  'company_form_code+CO_16',
#  'company_form_code+CO_53',
#  'company_form_code+CO_2',
#  'company_form_code+CO_10',
#  'company_form_code+CO_13',
#  'company_form_code+CO_19',
#  'company_form_code+CO_5',
#  'company_form_code+CO_14',
#  'company_form_code+CO_6',
#  'company_form_code+CO_63',
#  'company_form_code+CO_51',
#  'company_form_code+CO_56',
#  'company_form_code+CO_18',
#  'company_form_code+CO_60',
#  'company_form_code+CO_17',
#  'company_form_code+CO_0',
#  'company_form_code+CO_54',
#  'company_form_code+CO_52',
#  'company_form_code+CO_50',
#  'company_form_code+CO_57',
#  'company_form_code+CO_31',
#  'company_form_code+CO_29',
#  'company_form_code+CO_41',
#  'company_form_code+CO_71',
#  'company_form_code+CO_39',
#  'company_form_code+CO_36',
#  'company_form_code+CO_90',
#  'company_form_code+CO_48',
#  'company_form_code+CO_44',
#  'company_form_code+CO_59',
#  'company_form_code+CO_55',
#  'company_form_code+CO_42',
#  'company_form_code+CO_40',
#  'company_form_code+CO_15',
#  'company_form_code+CO_70',
#  'company_form_code+CO_58',
#  'company_form_code+CO_32',
#  'company_form_code+CO_46',
#  'company_form_code+CO_43',
#  'company_form_code+CO_47',
#  'company_form_code+CO_12',
#  'company_form_code+CO_24',
#  'company_form_code+CO_38',
#  'company_form_code+CO_49',
#  'company_form_code+CO_37',
#  'company_form_code+CO_4',
#  'company_form_code+CO_30',
#  'company_form_code+CO_21',
#  'company_form_code+CO_45',
#  'company_form_code+CO_22',
#  'company_form_code+CO_28',
#  'company_form_code+CO_9',
#  'company_form_code+CO_1',
#  'company_form_code+CO_35',
#  'company_form_code+CO_25',
#  'company_form_code+CO_3',
#  'company_form_code+CO_33',
#  'company_form_code+CO_20',
#  'company_form_code+CO_8',
#  'company_form_code+CO_7',
#  'company_form_code+NaN',
#  'company_form_code+CO_80',
#  'company_form_code+CO_61',
#  'company_form_code+CO_23',
#  'location_municipality_code+091',
#  'location_municipality_code+NaN',
#  'location_municipality_code+049',
#  'location_municipality_code+272',
#  'location_municipality_code+636',
#  'location_municipality_code+535',
#  'location_municipality_code+297',
#  'location_municipality_code+837',
#  'location_municipality_code+504',
#  'location_municipality_code+853',
#  'location_municipality_code+016',
#  'location_municipality_code+405',
#  'location_municipality_code+564',
#  'location_municipality_code+092',
#  'location_municipality_code+186',
#  'location_municipality_code+980',
#  'location_municipality_code+859',
#  'location_municipality_code+707',
#  'location_municipality_code+499',
#  'location_municipality_code+545',
#  'location_municipality_code+743',
#  'location_municipality_code+005',
#  'location_municipality_code+678',
#  'location_municipality_code+758',
#  'location_municipality_code+402',
#  'location_municipality_code+753',
#  'location_municipality_code+179',
#  'location_municipality_code+244',
#  'location_municipality_code+410',
#  'location_municipality_code+536',
#  'location_municipality_code+245',
#  'location_municipality_code+286',
#  'location_municipality_code+061',
#  'location_municipality_code+505',
#  'location_municipality_code+430',
#  'location_municipality_code+109',
#  'location_municipality_code+398',
#  'location_municipality_code+018',
#  'location_municipality_code+436',
#  'location_municipality_code+740',
#  'location_municipality_code+858',
#  'location_municipality_code+927',
#  'location_municipality_code+563',
#  'location_municipality_code+620',
#  'location_municipality_code+895',
#  'location_municipality_code+508',
#  'location_municipality_code+765',
#  'location_municipality_code+844',
#  'location_municipality_code+106',
#  'location_municipality_code+851',
#  'location_municipality_code+905',
#  'location_municipality_code+759',
#  'location_municipality_code+235',
#  'location_municipality_code+543',
#  'location_municipality_code+202',
#  'location_municipality_code+749',
#  'location_municipality_code+478',
#  'location_municipality_code+680',
#  'location_municipality_code+285',
#  'location_municipality_code+781',
#  'location_municipality_code+734',
#  'location_municipality_code+925',
#  'location_municipality_code+494',
#  'location_municipality_code+915',
#  'location_municipality_code+694',
#  'location_municipality_code+075',
#  'location_municipality_code+908',
#  'location_municipality_code+165',
#  'location_municipality_code+213',
#  'location_municipality_code+681',
#  'location_municipality_code+224',
#  'location_municipality_code+140',
#  'location_municipality_code+702',
#  'location_municipality_code+710',
#  'location_municipality_code+211',
#  'location_municipality_code+791',
#  'location_municipality_code+261',
#  'location_municipality_code+638',
#  'location_municipality_code+440',
#  'location_municipality_code+176',
#  'location_municipality_code+273',
#  'location_municipality_code+169',
#  'location_municipality_code+698',
#  'location_municipality_code+182',
#  'location_municipality_code+263',
#  'location_municipality_code+233',
#  'location_municipality_code+108',
#  'location_municipality_code+615',
#  'location_municipality_code+167',
#  'location_municipality_code+418',
#  'location_municipality_code+204',
#  'location_municipality_code+205',
#  'location_municipality_code+748',
#  'location_municipality_code+609',
#  'location_municipality_code+577',
#  'location_municipality_code+170',
#  'location_municipality_code+500',
#  'location_municipality_code+232',
#  'location_municipality_code+098',
#  'location_municipality_code+444',
#  'location_municipality_code+593',
#  'location_municipality_code+529',
#  'location_municipality_code+778',
#  'location_municipality_code+491',
#  'location_municipality_code+616',
#  'location_municipality_code+924',
#  'location_municipality_code+738',
#  'location_municipality_code+153',
#  'location_municipality_code+051',
#  'location_municipality_code+495',
#  'location_municipality_code+399',
#  'location_municipality_code+684',
#  'location_municipality_code+423',
#  'location_municipality_code+561',
#  'location_municipality_code+260',
#  'location_municipality_code+831',
#  'location_municipality_code+790',
#  'location_municipality_code+214',
#  'location_municipality_code+611',
#  'location_municipality_code+218',
#  'location_municipality_code+241',
#  'location_municipality_code+777',
#  'location_municipality_code+601',
#  'location_municipality_code+977',
#  'location_municipality_code+433',
#  'location_municipality_code+562',
#  'location_municipality_code+434',
#  'location_municipality_code+305',
#  'location_municipality_code+408',
#  'location_municipality_code+976',
#  'location_municipality_code+560',
#  'location_municipality_code+890',
#  'location_municipality_code+435',
#  'location_municipality_code+047',
#  'location_municipality_code+541',
#  'location_municipality_code+145',
#  'location_municipality_code+078',
#  'location_municipality_code+271',
#  'location_municipality_code+322',
#  'location_municipality_code+149',
#  'location_municipality_code+946',
#  'location_municipality_code+992',
#  'location_municipality_code+240',
#  'location_municipality_code+941',
#  'location_municipality_code+079',
#  'location_municipality_code+592',
#  'location_municipality_code+635',
#  'location_municipality_code+257',
#  'location_municipality_code+226',
#  'location_municipality_code+102',
#  'location_municipality_code+886',
#  'location_municipality_code+146',
#  'location_municipality_code+400',
#  'location_municipality_code+892',
#  'location_municipality_code+531',
#  'location_municipality_code+761',
#  'location_municipality_code+426',
#  'location_municipality_code+584',
#  'location_municipality_code+276',
#  'location_municipality_code+507',
#  'location_municipality_code+111',
#  'location_municipality_code+689',
#  'location_municipality_code+256',
#  'location_municipality_code+484',
#  'location_municipality_code+143',
#  'location_municipality_code+475',
#  'location_municipality_code+686',
#  'location_municipality_code+445',
#  'location_municipality_code+887',
#  'location_municipality_code+704',
#  'location_municipality_code+086',
#  'location_municipality_code+250',
#  'location_municipality_code+598',
#  'location_municipality_code+069',
#  'location_municipality_code+090',
#  'location_municipality_code+607',
#  'location_municipality_code+236',
#  'location_municipality_code+291',
#  'location_municipality_code+834',
#  'location_municipality_code+425',
#  'location_municipality_code+148',
#  'location_municipality_code+301',
#  'location_municipality_code+619',
#  'location_municipality_code+503',
#  'location_municipality_code+422',
#  'location_municipality_code+249',
#  'location_municipality_code+989',
#  'location_municipality_code+217',
#  'location_municipality_code+700',
#  'location_municipality_code+729',
#  'location_municipality_code+481',
#  'location_municipality_code+178',
#  'location_municipality_code+172',
#  'location_municipality_code+081',
#  'location_municipality_code+889',
#  'location_municipality_code+151',
#  'location_municipality_code+312',
#  'location_municipality_code+071',
#  'location_municipality_code+604',
#  'location_municipality_code+139',
#  'location_municipality_code+498',
#  'location_municipality_code+420',
#  'location_municipality_code+020',
#  'location_municipality_code+050',
#  'location_municipality_code+317',
#  'location_municipality_code+077',
#  'location_municipality_code+783',
#  'location_municipality_code+846',
#  'location_municipality_code+316',
#  'location_municipality_code+936',
#  'location_municipality_code+082',
#  'location_municipality_code+538',
#  'location_municipality_code+035',
#  'location_municipality_code+290',
#  'location_municipality_code+309',
#  'location_municipality_code+683',
#  'location_municipality_code+320',
#  'location_municipality_code+595',
#  'location_municipality_code+608',
#  'location_municipality_code+171',
#  'location_municipality_code+280',
#  'location_municipality_code+441',
#  'location_municipality_code+691',
#  'location_municipality_code+480',
#  'location_municipality_code+580',
#  'location_municipality_code+931',
#  'location_municipality_code+052',
#  'location_municipality_code+208',
#  'location_municipality_code+287',
#  'location_municipality_code+288',
#  'location_municipality_code+755',
#  'location_municipality_code+849',
#  'location_municipality_code+751',
#  'location_municipality_code+934',
#  'location_municipality_code+626',
#  'location_municipality_code+181',
#  'location_municipality_code+599',
#  'location_municipality_code+581',
#  'location_municipality_code+762',
#  'location_municipality_code+588',
#  'location_municipality_code+768',
#  'location_municipality_code+152',
#  'location_municipality_code+060',
#  'location_municipality_code+417',
#  'location_municipality_code+893',
#  'location_municipality_code+142',
#  'location_municipality_code+832',
#  'location_municipality_code+230',
#  'location_municipality_code+747',
#  'location_municipality_code+732',
#  'location_municipality_code+631',
#  'location_municipality_code+010',
#  'location_municipality_code+845',
#  'location_municipality_code+583',
#  'location_municipality_code+576',
#  'location_municipality_code+578',
#  'location_municipality_code+304',
#  'location_municipality_code+687',
#  'location_municipality_code+043',
#  'location_municipality_code+746',
#  'location_municipality_code+742',
#  'location_municipality_code+483',
#  'location_municipality_code+009',
#  'location_municipality_code+850',
#  'location_municipality_code+239',
#  'location_municipality_code+097',
#  'location_municipality_code+624',
#  'location_municipality_code+785',
#  'location_municipality_code+318',
#  'location_municipality_code+076',
#  'location_municipality_code+848',
#  'location_municipality_code+739',
#  'location_municipality_code+771',
#  'location_municipality_code+614',
#  'location_municipality_code+275',
#  'location_municipality_code+922',
#  'location_municipality_code+103',
#  'location_municipality_code+981',
#  'location_municipality_code+265',
#  'location_municipality_code+019',
#  'location_municipality_code+403',
#  'location_municipality_code+854',
#  'location_municipality_code+623',
#  'location_municipality_code+630',
#  'location_municipality_code+625',
#  'location_municipality_code+231',
#  'location_municipality_code+918',
#  'location_municipality_code+062',
#  'location_municipality_code+416',
#  'location_municipality_code+074',
#  'location_municipality_code+300',
#  'location_municipality_code+407',
#  'location_municipality_code+935',
#  'location_municipality_code+736',
#  'location_municipality_code+072',
#  'location_municipality_code+105',
#  'location_municipality_code+833',
#  'location_municipality_code+216',
#  'location_municipality_code+857',
#  'location_municipality_code+284',
#  'location_municipality_code+489',
#  'location_municipality_code+438',
#  'location_municipality_code+921',
#  'location_municipality_code+421',
#  'location_municipality_code+065',
#  'location_municipality_code+177',
#  'location_municipality_code+295',
#  'location_municipality_code+046',
#  'location_municipality_code+766',
#  'location_municipality_code+697',
#  'location_region_code+01',
#  'location_region_code+NaN',
#  'location_region_code+16',
#  'location_region_code+02',
#  'location_region_code+17',
#  'location_region_code+11',
#  'location_region_code+06',
#  'location_region_code+07',
#  'location_region_code+09',
#  'location_region_code+12',
#  'location_region_code+15',
#  'location_region_code+14',
#  'location_region_code+19',
#  'location_region_code+13',
#  'location_region_code+08',
#  'location_region_code+05',
#  'location_region_code+10',
#  'location_region_code+18',
#  'location_region_code+21',
#  'location_region_code+04',
#  'company_status_code+AKT',
#  'company_status_code+SELTILA',
#  'company_status_code+KESK',
#  'company_status_code+KONK',
#  'company_status_code+SANE',
#  'industry_code+43',
#  'industry_code+68',
#  'industry_code+74',
#  'industry_code+NaN',
#  'industry_code+49',
#  'industry_code+01',
#  'industry_code+46',
#  'industry_code+90',
#  'industry_code+86',
#  'industry_code+56',
#  'industry_code+79',
#  'industry_code+41',
#  'industry_code+62',
#  'industry_code+87',
#  'industry_code+93',
#  'industry_code+81',
#  'industry_code+47',
#  'industry_code+22',
#  'industry_code+33',
#  'industry_code+71',
#  'industry_code+85',
#  'industry_code+45',
#  'industry_code+69',
#  'industry_code+18',
#  'industry_code+31',
#  'industry_code+25',
#  'industry_code+02',
#  'industry_code+59',
#  'industry_code+66',
#  'industry_code+70',
#  'industry_code+64',
#  'industry_code+10',
#  'industry_code+88',
#  'industry_code+14',
#  'industry_code+82',
#  'industry_code+55',
#  'industry_code+52',
#  'industry_code+96',
#  'industry_code+73',
#  'industry_code+77',
#  'industry_code+28',
#  'industry_code+61',
#  'industry_code+95',
#  'industry_code+80',
#  'industry_code+13',
#  'industry_code+63',
#  'industry_code+16',
#  'industry_code+03',
#  'industry_code+42',
#  'industry_code+17',
#  'industry_code+32',
#  'industry_code+26',
#  'industry_code+35',
#  'industry_code+08',
#  'industry_code+75',
#  'industry_code+36',
#  'industry_code+78',
#  'industry_code+53',
#  'industry_code+00',
#  'industry_code+94',
#  'industry_code+23',
#  'industry_code+27',
#  'industry_code+72',
#  'industry_code+38',
#  'industry_code+58',
#  'industry_code+20',
#  'industry_code+29',
#  'industry_code+37',
#  'industry_code+65',
#  'industry_code+30',
#  'industry_code+50',
#  'industry_code+84',
#  'industry_code+91',
#  'industry_code+99',
#  'industry_code+11',
#  'industry_code+21',
#  'industry_code+15',
#  'industry_code+60',
#  'industry_code+24',
#  'industry_code+09',
#  'industry_code+51',
#  'industry_code+39',
#  'industry_code+07',
#  'industry_code+97',
#  'industry_code+92',
#  'industry_code+19',
#  'industry_code+98',
#  'industry_code+06',
#  'industry_code+12',
#  'industry_code+05',
#  'turnover+NaN',
#  'turnover+0.2',
#  'turnover+0.95',
#  'turnover+0.4',
#  'turnover+0.8',
#  'turnover+0.9',
#  'turnover+0.6',
#  'turnover+top',
#  'turnover+0.98',
#  'net_profit+NaN',
#  'net_profit+0.8',
#  'net_profit+0.2',
#  'net_profit+0.6',
#  'net_profit+0.9',
#  'net_profit+0.98',
#  'net_profit+0.4',
#  'net_profit+0.95',
#  'net_profit+top',
#  'personnel_average+NaN',
#  'personnel_average+0.4',
#  'personnel_average+0.9',
#  'personnel_average+0.8',
#  'personnel_average+0.6',
#  'personnel_average+0.2',
#  'personnel_average+0.95',
#  'personnel_average+0.98',
#  'personnel_average+top',
#  'performer_ranking_points+NaN',
#  'performer_ranking_points+0.9',
#  'performer_ranking_points+0.4',
#  'performer_ranking_points+0.95',
#  'performer_ranking_points+0.6',
#  'performer_ranking_points+0.8',
#  'performer_ranking_points+0.2',
#  'performer_ranking_points+0.98',
#  'performer_ranking_points+top',
#  'risk_rating_class+NaN',
#  'risk_rating_class+GREEN',
#  'risk_rating_class+YELLOW',
#  'risk_rating_class+RED']

# %% [markdown]
# ## Lasketaan gini-indeksit

# %%
def calculate_gini_for_word(word):
    col_name = word.split('+')[0]
    matches_df = COMPANIES_DF[COMPANIES_DF[col_name] == word]
    
    matched_docs_total = matches_df.shape[0]
    
    match_bids = list(matches_df['business_id'].unique())
    
    matching_interactions_df = INTERACTIONS_DF[INTERACTIONS_DF['business_id'].isin(match_bids)]
    
    interacted_docs_count = matching_interactions_df['business_id'].unique().shape[0]
    non_interacted_docs_count = matched_docs_total - interacted_docs_count
    
    gini_index = 1 - ((interacted_docs_count / matched_docs_total) ** 2 + \
                    (non_interacted_docs_count / matched_docs_total) ** 2)
    
        
    return (word, gini_index, interacted_docs_count, matched_docs_total)

# %%
print(calculate_gini_for_word('location_municipality_code+NaN'))
# Out:
# ('location_municipality_code+NaN', 0.08463206422198355, 39337, 888441)

# %%
GINI_SCORES = []

for word in FEATURES:
    gini = calculate_gini_for_word(word)
    GINI_SCORES.append(gini)

# %%
GINI_DF = pd.DataFrame(GINI_SCORES, columns=['feature', 'gini_score', 'interacted_count', 'total_count'])
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(GINI_DF.sort_values('gini_score'))
# Out:
#                             feature  gini_score  interacted_count  total_count
# 487                industry_code+06    0.000000                 0            2
# 36          company_form_code+CO_58    0.000000                 0           24
# 48          company_form_code+CO_21    0.000000                 0            3
# 51          company_form_code+CO_28    0.000000                 0            5
# 52           company_form_code+CO_9    0.000000                 1            1
# 53           company_form_code+CO_1    0.000000                 0            5
# 54          company_form_code+CO_35    0.000000                 0            9
# 27          company_form_code+CO_90    0.000000                 0           54
# 56           company_form_code+CO_3    0.000000                 0            2
# 58          company_form_code+CO_20    0.000000                13           13
# 16           company_form_code+CO_0    0.000000                 0         2915
# 60           company_form_code+CO_7    0.000000                 0            2
# 59           company_form_code+CO_8    0.000000                 0            2
# 43          company_form_code+CO_38    0.000000                 0           63
# 483                industry_code+97    0.000000                 0           58
# 488                industry_code+12    0.000000                 0            3
# 489                industry_code+05    0.000000                 0            1
# 64          company_form_code+CO_23    0.000000                 1            1
# 63          company_form_code+CO_61    0.000000                 0            2
# 61            company_form_code+NaN    0.000000                 0            2
# 2           company_form_code+CO_53    0.002522               116        91879
# 403               industry_code+NaN    0.002790               352       251987
# 516           personnel_average+top    0.004843              1233         1236
# 3            company_form_code+CO_2    0.005857               267        90904
# 31          company_form_code+CO_55    0.009740                 3          613
# 11          company_form_code+CO_51    0.010182               394        76992
# 17          company_form_code+CO_54    0.011027                11         1984
# 497                    turnover+top    0.011474              3446         3466
# 24          company_form_code+CO_71    0.011560                 2          344
# 515          personnel_average+0.98    0.011796              1843         1854
# 19          company_form_code+CO_50    0.012650                59         9269
# 10          company_form_code+CO_63    0.014579                34         4630
# 18          company_form_code+CO_52    0.014759                 4          538
# 12          company_form_code+CO_56    0.017803                 3          334
# 15          company_form_code+CO_17    0.021365               458          463
# 426                industry_code+02    0.021509              2714       249619
# 514          personnel_average+0.95    0.022017              3109         3144
# 458                industry_code+00    0.023198               113         9628
# 23          company_form_code+CO_41    0.025153               310          314
# 498                   turnover+0.98    0.025442              5132         5199
# 22          company_form_code+CO_29    0.030347                 9          584
# 405                industry_code+01    0.035676              1524        83884
# 447                industry_code+03    0.039033                78         3917
# 0           company_form_code+CO_26    0.040645             12440       599419
# 38          company_form_code+CO_46    0.043457                 4          180
# 20          company_form_code+CO_57    0.046796                28         1168
# 499                  net_profit+NaN    0.051237             29446      1119156
# 289  location_municipality_code+580    0.051378               369          379
# 14          company_form_code+CO_60    0.054727               401        14242
# 492                   turnover+0.95    0.058861              8402         8665
# 486                industry_code+98    0.060547                 1           32
# 30          company_form_code+CO_59    0.061288                 5          158
# 4           company_form_code+CO_10    0.062953               322         9897
# 510           personnel_average+0.9    0.070346              6176         6410
# 490                    turnover+NaN    0.070865             42840      1164583
# 286  location_municipality_code+441    0.072361               384          399
# 407                industry_code+90    0.074726               605        15563
# 21          company_form_code+CO_31    0.079861                38          912
# 9            company_form_code+CO_6    0.083383              4756       109103
# 517    performer_ranking_points+NaN    0.084567             53126      1200846
# 66   location_municipality_code+NaN    0.084632             39337       888441
# 376        location_region_code+NaN    0.085022             39583       889703
# 507                  net_profit+top    0.092218              4163         4375
# 526           risk_rating_class+NaN    0.092403             58768      1210224
# 401                industry_code+68    0.093098              7145       145982
# 474                industry_code+11    0.100837               320          338
# 457                industry_code+53    0.105469               104         1862
# 353  location_municipality_code+416    0.106328               134          142
# 41          company_form_code+CO_12    0.117188                30           32
# 437                industry_code+96    0.119132              2333        36675
# 431                industry_code+10    0.127762              2784         2989
# 397        company_status_code+KESK    0.134257               138         1907
# 473                industry_code+99    0.139551                 8          106
# 508           personnel_average+NaN    0.139930             96593      1276086
# 373  location_municipality_code+766    0.142012                 1           13
# 34          company_form_code+CO_15    0.145429               140          152
# 454                industry_code+75    0.147415               175         2184
# 414                industry_code+93    0.157280              1807        21001
# 459                industry_code+94    0.166254              4018        43913
# 26          company_form_code+CO_36    0.168740                12          129
# 415                industry_code+81    0.170131              1618        17235
# 307  location_municipality_code+060    0.174416                25          259
# 511           personnel_average+0.8    0.181694             12462        13863
# 7            company_form_code+CO_5    0.188716               975         9243
# 395         company_status_code+AKT    0.190700            141760      1328032
# 285  location_municipality_code+280    0.192189                28          260
# 334  location_municipality_code+076    0.193352                18          166
# 208  location_municipality_code+941    0.193762                 5           46
# 433                industry_code+14    0.196429               312         2826
# 369  location_municipality_code+065    0.197531                 6           54
# 5           company_form_code+CO_13    0.198205              2858        25622
# 326  location_municipality_code+483    0.200312                 7           62
# 343  location_municipality_code+265    0.209751                10           84
# 362  location_municipality_code+216    0.209751                15          126
# 358  location_municipality_code+736    0.211200                15          125
# 308  location_municipality_code+417    0.212247                14          116
# 197  location_municipality_code+435    0.214568                11           90
# 504                 net_profit+0.98    0.214624              5765         6568
# 342  location_municipality_code+981    0.215858                24          195
# 47          company_form_code+CO_30    0.218750                 2           16
# 495                    turnover+0.9    0.222983             15126        17343
# 149  location_municipality_code+263    0.223144                87          680
# 371  location_municipality_code+295    0.223537                 5           39
# 332  location_municipality_code+785    0.224082                27          210
# 233  location_municipality_code+887    0.225720                52          401
# 49          company_form_code+CO_45    0.226843                 3           23
# 240  location_municipality_code+607    0.226843                39          299
# 277  location_municipality_code+035    0.227608                11           84
# 297  location_municipality_code+751    0.227896                24          183
# 374  location_municipality_code+697    0.228140                13           99
# 438                industry_code+73    0.229685              1018         7691
# 143  location_municipality_code+440    0.229747                38          287
# 294  location_municipality_code+288    0.231281                77          577
# 432                industry_code+88    0.231810               936         6995
# 107  location_municipality_code+563    0.232368                73          544
# 205  location_municipality_code+946    0.233156                90          668
# 484                industry_code+92    0.233747                10           74
# 428                industry_code+66    0.234728              1222         8998
# 410                industry_code+79    0.234986               441         3243
# 309  location_municipality_code+893    0.235998                98          717
# 363  location_municipality_code+857    0.236233                26          190
# 301  location_municipality_code+599    0.239762                89          639
# 322  location_municipality_code+687    0.239855                17          122
# 325  location_municipality_code+742    0.240800                14          100
# 402                industry_code+74    0.241758              2916        20730
# 276  location_municipality_code+538    0.241768                46          327
# 287  location_municipality_code+691    0.242757                27          191
# 442                industry_code+95    0.242991               440         3109
# 313  location_municipality_code+747    0.243373                19          134
# 89   location_municipality_code+402    0.243449               100          705
# 39          company_form_code+CO_43    0.244898                 2           14
# 434                industry_code+82    0.246164               787         5475
# 360  location_municipality_code+105    0.247351                24          166
# 393         location_region_code+21    0.247865               507         3498
# 352  location_municipality_code+062    0.248179                 9           62
# 372  location_municipality_code+046    0.249463                13           89
# 299  location_municipality_code+626    0.250026                58          396
# 367  location_municipality_code+921    0.252737                23          155
# 408                industry_code+86    0.258762              4910        32155
# 121  location_municipality_code+478    0.259164               274         1791
# 319  location_municipality_code+576    0.259577                42          274
# 340  location_municipality_code+922    0.259726                52          339
# 55          company_form_code+CO_25    0.260355                 2           13
# 157  location_municipality_code+748    0.260633                59          383
# 127  location_municipality_code+494    0.262320                84          541
# 476                industry_code+15    0.262716                56          360
# 108  location_municipality_code+620    0.263210                29          186
# 259  location_municipality_code+889    0.264266                34          217
# 270  location_municipality_code+077    0.264345                50          319
# 84   location_municipality_code+545    0.264948               185         1177
# 349  location_municipality_code+625    0.265196                31          197
# 160  location_municipality_code+170    0.265761                68          431
# 220  location_municipality_code+761    0.266502               139          878
# 430                industry_code+64    0.267249              1713        10783
# 124  location_municipality_code+781    0.267716                64          402
# 230  location_municipality_code+475    0.269035                74          462
# 236  location_municipality_code+250    0.271309                28          173
# 226  location_municipality_code+689    0.271731                36          222
# 248  location_municipality_code+503    0.273386               108          661
# 175  location_municipality_code+399    0.274008                97          592
# 186  location_municipality_code+777    0.274411                87          530
# 329  location_municipality_code+239    0.274844                25          152
# 210  location_municipality_code+592    0.275937                40          242
# 174  location_municipality_code+495    0.276025                21          127
# 444                industry_code+13    0.276902               295         1777
# 144  location_municipality_code+176    0.277151                59          355
# 50          company_form_code+CO_22    0.277778                 4           24
# 203  location_municipality_code+322    0.278372               125          748
# 249  location_municipality_code+422    0.278616               133          795
# 468                industry_code+65    0.278707                80          478
# 83   location_municipality_code+499    0.278782               259         1547
# 427                industry_code+59    0.279521               748         4453
# 199  location_municipality_code+541    0.280070               114          677
# 114  location_municipality_code+851    0.280231               274         1626
# 196  location_municipality_code+890    0.280897                24          142
# 312  location_municipality_code+230    0.281264                43          254
# 385         location_region_code+15    0.282155              2593        15256
# 282  location_municipality_code+595    0.282849                52          305
# 257  location_municipality_code+172    0.283352                88          515
# 227  location_municipality_code+256    0.283824                25          146
# 347  location_municipality_code+623    0.283908                37          216
# 304  location_municipality_code+588    0.284082                30          175
# 228  location_municipality_code+484    0.284082                42          245
# 450                industry_code+32    0.284422               530         3087
# 323  location_municipality_code+043    0.284668                22          128
# 327  location_municipality_code+009    0.285123                31          180
# 300  location_municipality_code+181    0.285643                29          168
# 337  location_municipality_code+771    0.286243                18          104
# 296  location_municipality_code+849    0.287116                45          259
# 288  location_municipality_code+480    0.287994                30          172
# 273  location_municipality_code+316    0.288358                58          332
# 293  location_municipality_code+287    0.288792               136          777
# 81   location_municipality_code+859    0.288836                66          377
# 140  location_municipality_code+791    0.289425                76          433
# 281  location_municipality_code+320    0.289845                99          563
# 187  location_municipality_code+601    0.290019                63          358
# 351  location_municipality_code+918    0.290384                49          278
# 134  location_municipality_code+681    0.290657                57          323
# 262  location_municipality_code+071    0.291011                76          430
# 341  location_municipality_code+103    0.291121                29          164
# 315  location_municipality_code+631    0.291243                23          130
# 69   location_municipality_code+636    0.291468               133          751
# 472                industry_code+91    0.291830                69          389
# 200  location_municipality_code+145    0.291861               168          947
# 202  location_municipality_code+271    0.292200               105          591
# 366  location_municipality_code+438    0.292346                 8           45
# 103  location_municipality_code+436    0.293367                25          140
# 184  location_municipality_code+218    0.294052                24          134
# 247  location_municipality_code+619    0.295200                45          250
# 392         location_region_code+18    0.295374               954         5296
# 151  location_municipality_code+108    0.295593               141          782
# 235  location_municipality_code+086    0.295797                85          471
# 88   location_municipality_code+758    0.296668               123          679
# 120  location_municipality_code+749    0.297333               224         1233
# 320  location_municipality_code+578    0.297521                42          231
# 245  location_municipality_code+148    0.297830               136          747
# 244  location_municipality_code+425    0.298274               112          614
# 237  location_municipality_code+598    0.298667               313         1713
# 145  location_municipality_code+273    0.299147               104          568
# 462                industry_code+72    0.299269               375         2047
# 155  location_municipality_code+204    0.299537                42          229
# 278  location_municipality_code+290    0.300323               106          576
# 138  location_municipality_code+710    0.300603               503         2730
# 317  location_municipality_code+845    0.301276                51          276
# 269  location_municipality_code+317    0.301341                39          211
# 130  location_municipality_code+075    0.301647               253         1367
# 229  location_municipality_code+143    0.301783               150          810
# 303  location_municipality_code+762    0.301783                45          243
# 339  location_municipality_code+275    0.302866                40          215
# 181  location_municipality_code+790    0.303130               412         2212
# 209  location_municipality_code+079    0.303179                87          467
# 111  location_municipality_code+765    0.303253               183          982
# 350  location_municipality_code+231    0.303361                22          118
# 291  location_municipality_code+052    0.303774                48          257
# 420                industry_code+85    0.304561              2552        13618
# 219  location_municipality_code+531    0.304888                73          389
# 115  location_municipality_code+905    0.305763               984         5224
# 266  location_municipality_code+420    0.306360               132          699
# 215  location_municipality_code+886    0.306572               172          910
# 173  location_municipality_code+051    0.306692               125          661
# 238  location_municipality_code+069    0.306793                98          518
# 380         location_region_code+11    0.307193              3299        17408
# 198  location_municipality_code+047    0.308102                39          205
# 328  location_municipality_code+850    0.308390                36          189
# 310  location_municipality_code+142    0.308806               108          566
# 265  location_municipality_code+498    0.309052                51          267
# 131  location_municipality_code+908    0.309073               247         1293
# 314  location_municipality_code+732    0.309194                56          293
# 156  location_municipality_code+205    0.309382               443         2316
# 190  location_municipality_code+562    0.309384               136          711
# 214  location_municipality_code+102    0.309488               195         1019
# 71   location_municipality_code+297    0.309569              1644         8588
# 365  location_municipality_code+489    0.309642                27          141
# 224  location_municipality_code+507    0.309842               101          527
# 87   location_municipality_code+678    0.310378               267         1390
# 75   location_municipality_code+016    0.310383               136          708
# 182  location_municipality_code+214    0.310609               219         1139
# 254  location_municipality_code+729    0.310651               160          832
# 346  location_municipality_code+854    0.311085                63          327
# 429                industry_code+70    0.312483              5470        28225
# 137  location_municipality_code+702    0.313185                76          391
# 195  location_municipality_code+560    0.313324               254         1306
# 267  location_municipality_code+020    0.313675               246         1263
# 280  location_municipality_code+683    0.314007                63          323
# 216  location_municipality_code+146    0.314256                74          379
# 211  location_municipality_code+635    0.314562               113          578
# 206  location_municipality_code+992    0.314790               227         1160
# 231  location_municipality_code+686    0.314839                55          281
# 252  location_municipality_code+217    0.315046                86          439
# 148  location_municipality_code+182    0.315206               326         1663
# 506                 net_profit+0.95    0.315289              8822        10974
# 387         location_region_code+19    0.315611              2809        14305
# 232  location_municipality_code+445    0.315860               298         1516
# 345  location_municipality_code+403    0.316201                50          254
# 268  location_municipality_code+050    0.316211               188          955
# 283  location_municipality_code+608    0.317025                32          162
# 256  location_municipality_code+178    0.317685               103          520
# 355  location_municipality_code+300    0.317764                64          323
# 146  location_municipality_code+169    0.318011                72          363
# 225  location_municipality_code+111    0.318407               270         1359
# 331  location_municipality_code+624    0.318725                75          377
# 416                industry_code+47    0.319167              7765        38960
# 192  location_municipality_code+305    0.319174               232         1164
# 338  location_municipality_code+614    0.320000                44          220
# 125  location_municipality_code+734    0.320000               939         4695
# 100  location_municipality_code+109    0.320045              1056         5279
# 221  location_municipality_code+426    0.320537               179          893
# 344  location_municipality_code+019    0.320566                85          424
# 250  location_municipality_code+249    0.321629               148          735
# 152  location_municipality_code+615    0.321677               115          571
# 162  location_municipality_code+232    0.322214               240         1189
# 194  location_municipality_code+976    0.322229                65          322
# 243  location_municipality_code+834    0.322264                64          317
# 271  location_municipality_code+783    0.322522               115          569
# 394         location_region_code+04    0.322971              3356        16574
# 389         location_region_code+08    0.323315              2294        11313
# 189  location_municipality_code+433    0.324192               139          683
# 141  location_municipality_code+261    0.324472               163          800
# 110  location_municipality_code+508    0.324645               157          770
# 379         location_region_code+17    0.325560              5768        28182
# 123  location_municipality_code+285    0.325595               697         3405
# 218  location_municipality_code+892    0.325853                50          244
# 188  location_municipality_code+977    0.326331               216         1052
# 272  location_municipality_code+846    0.326442                91          443
# 112  location_municipality_code+844    0.326744                29          141
# 207  location_municipality_code+240    0.326824               215         1045
# 96   location_municipality_code+286    0.327083              1071         5200
# 306  location_municipality_code+152    0.328100               103          498
# 255  location_municipality_code+481    0.328304               136          657
# 356  location_municipality_code+407    0.328339                53          256
# 158  location_municipality_code+609    0.328545              1288         6216
# 129  location_municipality_code+694    0.328588               452         2181
# 204  location_municipality_code+149    0.328650               125          603
# 390         location_region_code+05    0.328986              2644        12737
# 382         location_region_code+07    0.328988              3103        14948
# 253  location_municipality_code+700    0.329379                63          303
# 311  location_municipality_code+832    0.329861                45          216
# 377         location_region_code+16    0.329880              1068         5126
# 133  location_municipality_code+213    0.330657               102          488
# 73   location_municipality_code+504    0.330684                37          177
# 68   location_municipality_code+272    0.330920               729         3484
# 398        company_status_code+KONK    0.331437              1052         5017
# 170  location_municipality_code+924    0.332125                45          214
# 147  location_municipality_code+698    0.332604              1060         5031
# 213  location_municipality_code+226    0.333453                74          350
# 136  location_municipality_code+140    0.333489               310         1466
# 165  location_municipality_code+593    0.335028               296         1391
# 117  location_municipality_code+235    0.335208               194          911
# 93   location_municipality_code+410    0.335364               267         1253
# 126  location_municipality_code+925    0.335765                54          253
# 284  location_municipality_code+171    0.336036                75          351
# 77   location_municipality_code+564    0.336082              3051        14276
# 101  location_municipality_code+398    0.336216              1920         8979
# 384         location_region_code+12    0.336378              2398        11207
# 279  location_municipality_code+309    0.336549                94          439
# 42          company_form_code+CO_24    0.336735                11           14
# 264  location_municipality_code+139    0.336890               113          527
# 404                industry_code+49    0.337608              4938        22962
# 168  location_municipality_code+491    0.338287               860         3988
# 180  location_municipality_code+831    0.338331                66          306
# 260  location_municipality_code+151    0.338331                44          204
# 193  location_municipality_code+408    0.338350               261         1210
# 167  location_municipality_code+778    0.338705               116          537
# 150  location_municipality_code+233    0.338847               308         1425
# 251  location_municipality_code+989    0.338872               107          495
# 316  location_municipality_code+010    0.339099               201          929
# 159  location_municipality_code+577    0.339193               179          827
# 99   location_municipality_code+430    0.339241               302         1395
# 388         location_region_code+13    0.339293              4508        20819
# 246  location_municipality_code+301    0.339413               388         1791
# 391         location_region_code+10    0.339597              2444        11273
# 370  location_municipality_code+177    0.339984                38          175
# 274  location_municipality_code+936    0.340095               126          580
# 241  location_municipality_code+236    0.340118                73          336
# 116  location_municipality_code+759    0.340265                50          230
# 330  location_municipality_code+097    0.340265                40          184
# 94   location_municipality_code+536    0.340939               492         2257
# 223  location_municipality_code+276    0.341088               195          894
# 242  location_municipality_code+291    0.341797                49          224
# 135  location_municipality_code+224    0.341904               144          658
# 201  location_municipality_code+078    0.341941               160          731
# 70   location_municipality_code+535    0.342544               165          752
# 212  location_municipality_code+257    0.342729               711         3238
# 298  location_municipality_code+934    0.342899                49          223
# 381         location_region_code+06    0.343014              8572        38993
# 321  location_municipality_code+304    0.343200                33          150
# 132  location_municipality_code+165    0.344124               246         1114
# 456                industry_code+78    0.344708               761         3438
# 290  location_municipality_code+931    0.344977               117          528
# 378         location_region_code+02    0.345937              8837        39725
# 128  location_municipality_code+915    0.346024               318         1429
# 79   location_municipality_code+186    0.346387               776         3482
# 72   location_municipality_code+837    0.346500              4185        18770
# 166  location_municipality_code+529    0.346703               376         1685
# 261  location_municipality_code+312    0.346990                21           94
# 222  location_municipality_code+584    0.347299                51          228
# 422                industry_code+69    0.347371              8531        10990
# 368  location_municipality_code+421    0.347516                15           67
# 163  location_municipality_code+098    0.347728               296         1321
# 178  location_municipality_code+561    0.348188                33          147
# 275  location_municipality_code+082    0.348481               138          614
# 153  location_municipality_code+167    0.348973              1167         5182
# 295  location_municipality_code+755    0.349066                98          435
# 217  location_municipality_code+400    0.349200               165          732
# 336  location_municipality_code+739    0.349636                63          279
# 364  location_municipality_code+284    0.349784                54          239
# 318  location_municipality_code+583    0.350823                27          119
# 302  location_municipality_code+581    0.351240               140          616
# 139  location_municipality_code+211    0.352083               509         2232
# 333  location_municipality_code+318    0.352653                 8           35
# 164  location_municipality_code+444    0.353009               838         3661
# 86   location_municipality_code+005    0.353452               169          737
# 80   location_municipality_code+980    0.353996               572         2489
# 348  location_municipality_code+630    0.354200                23          100
# 106  location_municipality_code+927    0.354568               621         2696
# 324  location_municipality_code+746    0.355030                75          325
# 122  location_municipality_code+680    0.355030               426         1846
# 176  location_municipality_code+684    0.355858               624         2695
# 292  location_municipality_code+208    0.356038               266         1148
# 305  location_municipality_code+768    0.356157                51          220
# 239  location_municipality_code+090    0.356505                65          280
# 91   location_municipality_code+179    0.357391              2483        10658
# 191  location_municipality_code+434    0.358037               320         1370
# 258  location_municipality_code+081    0.360561                63          267
# 74   location_municipality_code+853    0.360762              3635        15393
# 421                industry_code+45    0.361046              3994        16894
# 234  location_municipality_code+704    0.361268               115          486
# 113  location_municipality_code+106    0.362317               888         3737
# 142  location_municipality_code+638    0.364352              1091         4554
# 177  location_municipality_code+423    0.364468               331         1381
# 361  location_municipality_code+833    0.365032                43          179
# 102  location_municipality_code+018    0.366135                90          373
# 354  location_municipality_code+074    0.367309                24           99
# 109  location_municipality_code+895    0.367564               298         1228
# 185  location_municipality_code+241    0.367974               114          469
# 104  location_municipality_code+740    0.368471               614         2521
# 448                industry_code+42    0.368752               879         3605
# 357  location_municipality_code+935    0.370089                63          257
# 411                industry_code+41    0.370527              8308        33832
# 92   location_municipality_code+244    0.370576               280         1140
# 169  location_municipality_code+616    0.372462                49          198
# 90   location_municipality_code+753    0.373156               439         1769
# 183  location_municipality_code+611    0.373801               104          418
# 335  location_municipality_code+848    0.374230                81          325
# 512           personnel_average+0.6    0.374985             12301        16401
# 97   location_municipality_code+061    0.375000               339         1356
# 386         location_region_code+14    0.376058              4145        16510
# 470                industry_code+50    0.376213               155          617
# 82   location_municipality_code+707    0.379731                40          157
# 154  location_municipality_code+418    0.383167               451         1746
# 40          company_form_code+CO_47    0.383472                15           58
# 119  location_municipality_code+202    0.384610               656         2525
# 172  location_municipality_code+153    0.385388               442         1696
# 118  location_municipality_code+543    0.385455               915         3510
# 443                industry_code+80    0.385599               313         1200
# 423                industry_code+18    0.385812               425         1628
# 76   location_municipality_code+405    0.386990              1339         5105
# 445                industry_code+63    0.387299               588         2239
# 480                industry_code+51    0.388750                42          159
# 105  location_municipality_code+858    0.390096               963         3626
# 98   location_municipality_code+505    0.392208               379         1415
# 375         location_region_code+01    0.393591             42061       156164
# 67   location_municipality_code+049    0.394616              6410        23701
# 29          company_form_code+CO_44    0.394907                88          325
# 460                industry_code+23    0.395379               325         1198
# 477                industry_code+60    0.397915                37          135
# 494                    turnover+0.8    0.398171             25211        34743
# 179  location_municipality_code+260    0.398417               223          812
# 481                industry_code+39    0.399003                49          178
# 359  location_municipality_code+072    0.399524                24           87
# 396     company_status_code+SELTILA    0.402748               763         2730
# 161  location_municipality_code+500    0.403516               187          667
# 65   location_municipality_code+091    0.406103             20454        72193
# 513           personnel_average+0.2    0.406198               359          501
# 78   location_municipality_code+092    0.409242              4938        17207
# 452                industry_code+35    0.409735              1105         1551
# 171  location_municipality_code+738    0.412562                80          275
# 503                  net_profit+0.9    0.415444             15604        22114
# 525    performer_ranking_points+top    0.416880              2132         3029
# 35          company_form_code+CO_70    0.420000                 6           20
# 524   performer_ranking_points+0.98    0.422001              2716         3894
# 435                industry_code+55    0.422029              1209         3996
# 95   location_municipality_code+245    0.422054               761         2515
# 400                industry_code+43    0.423077             11103        36537
# 439                industry_code+77    0.425795               983         3198
# 399        company_status_code+SANE    0.426036               126          182
# 418                industry_code+33    0.429427              1572         5036
# 491                    turnover+0.2    0.430917             10828        34468
# 469                industry_code+30    0.432634               269          850
# 263  location_municipality_code+604    0.433440               450         1417
# 417                industry_code+22    0.434738               552          811
# 522    performer_ranking_points+0.8    0.435378             19271        28350
# 32          company_form_code+CO_42    0.437190               107          158
# 419                industry_code+71    0.437410              5239        16215
# 436                industry_code+52    0.437929              1136         3508
# 406                industry_code+46    0.440730              7476        22803
# 383         location_region_code+09    0.440788              2896         8831
# 85   location_municipality_code+743    0.441691              1883         5719
# 527         risk_rating_class+GREEN    0.442461             72573       108380
# 518    performer_ranking_points+0.9    0.442562              9323        13926
# 28          company_form_code+CO_48    0.444444                 2            3
# 520   performer_ranking_points+0.95    0.444795              5054         7587
# 519    performer_ranking_points+0.4    0.445319             18524        27841
# 425                industry_code+25    0.449232              2304         6763
# 528        risk_rating_class+YELLOW    0.450101              8156        12396
# 451                industry_code+26    0.452054               664         1014
# 505                  net_profit+0.4    0.456246              8797        24985
# 471                industry_code+84    0.456358               533         1513
# 521    performer_ranking_points+0.6    0.456402             16491        25463
# 502                  net_profit+0.6    0.457846             22496        63401
# 424                industry_code+31    0.458972               482         1351
# 412                industry_code+62    0.461378              6425        17796
# 523    performer_ranking_points+0.2    0.461514             17202        26932
# 446                industry_code+16    0.463366              1133         3107
# 25          company_form_code+CO_39    0.463571               142          389
# 8           company_form_code+CO_14    0.464249              1337         3650
# 461                industry_code+27    0.464284               422          666
# 529           risk_rating_class+RED    0.465042              4342         6868
# 440                industry_code+28    0.469165              1312         2102
# 33          company_form_code+CO_40    0.477502                80          132
# 479                industry_code+09    0.477839                60          152
# 453                industry_code+08    0.478174               496         1254
# 44          company_form_code+CO_49    0.480000                28           70
# 475                industry_code+21    0.480000                48           80
# 57          company_form_code+CO_33    0.480000                 6           10
# 493                    turnover+0.4    0.480257             13932        34774
# 46           company_form_code+CO_4    0.484429                 7           17
# 37          company_form_code+CO_32    0.486111                20           48
# 13          company_form_code+CO_18    0.487336              1482         3525
# 1           company_form_code+CO_16    0.487602            116100       275598
# 466                industry_code+29    0.488941               166          390
# 409                industry_code+56    0.489081              7500        17601
# 501                  net_profit+0.2    0.490439             23876        41951
# 467                industry_code+37    0.491618               158          363
# 500                  net_profit+0.8    0.492596             24870        44344
# 6           company_form_code+CO_19    0.495144               686         1522
# 465                industry_code+20    0.495389               331          604
# 496                    turnover+0.6    0.495684             18922        34627
# 441                industry_code+61    0.496065               405          744
# 455                industry_code+36    0.497644               658         1413
# 509           personnel_average+0.4    0.498031              9763        18373
# 464                industry_code+58    0.498117               910         1939
# 463                industry_code+38    0.498830               401          765
# 45          company_form_code+CO_37    0.499314                13           27
# 485                industry_code+19    0.499592                18           35
# 482                industry_code+07    0.499703                21           41
# 449                industry_code+17    0.499805               155          304
# 413                industry_code+87    0.499822               806         1643
# 62          company_form_code+CO_80    0.500000                 2            4
# 478                industry_code+24    0.500000                98          196
