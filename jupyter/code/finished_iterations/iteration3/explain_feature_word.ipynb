# %%
import numpy as np
import pandas as pd

WORKING_DIRECTORY = '/mnt/c/git/masters-thesis-code/jupyter/code/'

COMPANIES_DF = pd \
        .read_csv(WORKING_DIRECTORY + 'data/prod_data_companies_more_data_2021_09_16.csv',
                  delimiter='\t',
                  na_values='(null)',
                  dtype={
                      'business_id': str,
                      'business_id_start_date': str,
                      'company_name': str,
                      'email_address': str,
                      'industry_code': str,
                      'language': str,
                      'company_form': str,
                      'company_form_code': str,
                      'domicile_code': str,
                      'region_code': str,
                      'location_municipality_code': str,
                      'location_region_code': str,
                      'company_status_code': str,
                      'balance_industry_code': str,
                      'personnel_class': str,
                      'turnover_class': str,
                      'statement_date': str,
                      'statement_length': float,
                      'target_year': str,
                      'turnover': float,
                      'raw_materials_use': float,
                      'current_ratio': float,
                      'personnel_expenses': float,
                      'investment_expenses_cash_flow': float,
                      'ebitda': float,
                      'operating_profit_per_turnover': float,
                      'ebit': float,
                      'turnover_growth_percent': float,
                      'ebit_per_turnover': float,
                      'short_term_sales_receivable': float,
                      'net_profit': float,
                      'net_profit_per_turnover': float,
                      'aggregate_equity': float,
                      'return_on_equity_percent': float,
                      'equity_ratio': float,
                      'long_term_sales_receivable': float,
                      'quick_ratio': float,
                      'buildings': float,
                      'return_on_investment_percent': float,
                      'total_assets': float,
                      'external_services': float,
                      'aggregate_current_assets': float,
                      'personnel_average': float,
                      'concern': str,
                      'bulk': str,
                      'performer_ranking_points': float,
                      'risk_rating_class': str,
                      'latest': str
                  }
                  )

COMPANIES_DF.head()
# Out:
#   business_id business_id_start_date  \
# 0    31431209             2020-06-22
# 1    32087307             2021-05-04
# 2    18601103             2003-10-24
# 3    20469041             2006-07-04
# 4    24844507             2012-06-18
#
#                                company_name                    email_address  \
# 0                      Tmi Onerva Miettunen       onerva.adalmiina@gmail.com
# 1                      Koti Vaihtoon LKV Oy  matti.leskinen@kotivaihtoon.com
# 2  Teollisuuden Monialapalvelu T:mi Oksanen                              NaN
# 3                                  POLYBEAT                              NaN
# 4                               SAHOJEN PUU            kalle.kantola@hasa.fi
#
#   industry_code language                      company_form company_form_code  \
# 0         43341     CL_1  Yksityinen elinkeinonharjoittaja             CO_26
# 1         68310     CL_1                        Osakeyhtiö             CO_16
# 2         68209     CL_1  Yksityinen elinkeinonharjoittaja             CO_26
# 3         74909     CL_2                        Kuolinpesä             CO_53
# 4           NaN     CL_1  Yksityinen elinkeinonharjoittaja             CO_26
#
#   domicile_code region_code  ... return_on_investment_percent total_assets  \
# 0           091       RE_01  ...                          NaN          NaN
# 1           743       RE_14  ...                          NaN          NaN
# 2           179       RE_13  ...                          NaN          NaN
# 3           091       RE_01  ...                          NaN          NaN
# 4           069       RE_17  ...                          NaN          NaN
#
#   external_services aggregate_current_assets personnel_average concern bulk  \
# 0               NaN                      NaN               NaN     NaN  NaN
# 1               NaN                      NaN               NaN     NaN  NaN
# 2               NaN                      NaN               NaN     NaN  NaN
# 3               NaN                      NaN               NaN     NaN  NaN
# 4               NaN                      NaN               NaN     NaN  NaN
#
#    performer_ranking_points risk_rating_class  latest
# 0                       NaN               NaN     NaN
# 1                       NaN               NaN     NaN
# 2                       NaN               NaN     NaN
# 3                       NaN               NaN     NaN
# 4                       NaN               NaN     NaN
#
# [5 rows x 48 columns]

# %%
def find_rows_with_word(word):
    col_name, actual_word = word.split('+')
    print(col_name)
    print(actual_word)
    return COMPANIES_DF[COMPANIES_DF[col_name] == actual_word]

# %%
find_rows_with_word('company_form_code+CO_20')
# Out:
# company_form_code
# CO_20
#         business_id business_id_start_date                    company_name  \
# 293353     01844678             1978-03-15          Ylihärmän Säästöpankki
# 318646     01291831             1978-03-15          Myrskylän Säästöpankki
# 471870     01323266             1978-03-15           Eurajoen Säästöpankki
# 692699     01797322             1978-03-15              Avain Säästöpankki
# 859397     01352403             1978-03-15         Mietoisten Säästöpankki
# 919850     01334096             1978-03-15  Säästöpankki Kalanti-Pyhäranta
# 924953     01983686             1978-06-16                Kvevlax Sparbank
# 1016383    01978481             1978-06-16            Säästöpankki Sinetti
# 1147024    01283719             1978-03-15    Länsi-Uudenmaan Säästöpankki
# 1189518    01977948             1978-06-16             Lammin Säästöpankki
# 1234381    01347030             1978-03-15             Liedon Säästöpankki
# 1235584    01530919             1978-03-15            Someron Säästöpankki
# 1279161    01705598             1978-03-15              Säästöpankki Optia
#
#                                       email_address industry_code language  \
# 293353   yliharmansp.taloushallinto@saastopankki.fi         64190     CL_1
# 318646                                          NaN         64190     CL_1
# 471870                                          NaN         64190     CL_1
# 692699                                          NaN         64190     CL_1
# 859397                                          NaN         64190     CL_1
# 919850                                          NaN         64190     CL_1
# 924953                      kvevlaxsb@sparbanken.fi         64190     CL_2
# 1016383            etunimi.sukunimi@saastopankki.fi         64190     CL_1
# 1147024                                         NaN         64190     CL_1
# 1189518                                         NaN         64190     CL_1
# 1234381                                         NaN         64190     CL_1
# 1235584                                         NaN         64190     CL_1
# 1279161                                         NaN         64190     CL_1
#
#          company_form company_form_code domicile_code region_code  ...  \
# 293353   Säästöpankki             CO_20           233       RE_14  ...
# 318646   Säästöpankki             CO_20           504       RE_01  ...
# 471870   Säästöpankki             CO_20           051       RE_04  ...
# 692699   Säästöpankki             CO_20           233       RE_14  ...
# 859397   Säästöpankki             CO_20           503       RE_02  ...
# 919850   Säästöpankki             CO_20           895       RE_02  ...
# 924953   Säästöpankki             CO_20           499       RE_15  ...
# 1016383  Säästöpankki             CO_20           562       RE_06  ...
# 1147024  Säästöpankki             CO_20           444       RE_01  ...
# 1189518  Säästöpankki             CO_20           109       RE_05  ...
# 1234381  Säästöpankki             CO_20           423       RE_02  ...
# 1235584  Säästöpankki             CO_20           761       RE_02  ...
# 1279161  Säästöpankki             CO_20           140       RE_11  ...
#
#         return_on_investment_percent total_assets external_services  \
# 293353                           NaN          NaN               NaN
# 318646                           NaN          NaN               NaN
# 471870                           NaN          NaN               NaN
# 692699                           NaN          NaN               NaN
# 859397                           NaN          NaN               NaN
# 919850                           NaN          NaN               NaN
# 924953                           NaN          NaN               NaN
# 1016383                          NaN          NaN               NaN
# 1147024                          NaN          NaN               NaN
# 1189518                          NaN          NaN               NaN
# 1234381                          NaN          NaN               NaN
# 1235584                          NaN          NaN               NaN
# 1279161                          NaN          NaN               NaN
#
#         aggregate_current_assets personnel_average concern bulk  \
# 293353                       NaN               NaN     NaN  NaN
# 318646                       NaN               NaN     NaN  NaN
# 471870                       NaN               NaN     NaN  NaN
# 692699                       NaN               NaN     NaN  NaN
# 859397                       NaN               NaN     NaN  NaN
# 919850                       NaN               NaN     NaN  NaN
# 924953                       NaN               NaN     NaN  NaN
# 1016383                      NaN               NaN     NaN  NaN
# 1147024                      NaN               NaN     NaN  NaN
# 1189518                      NaN               NaN     NaN  NaN
# 1234381                      NaN               NaN     NaN  NaN
# 1235584                      NaN               NaN     NaN  NaN
# 1279161                      NaN               NaN     NaN  NaN
#
#          performer_ranking_points risk_rating_class  latest
# 293353                        NaN               NaN     NaN
# 318646                        NaN               NaN     NaN
# 471870                        NaN               NaN     NaN
# 692699                        NaN               NaN     NaN
# 859397                        NaN               NaN     NaN
# 919850                        NaN               NaN     NaN
# 924953                        NaN               NaN     NaN
# 1016383                       NaN               NaN     NaN
# 1147024                       NaN               NaN     NaN
# 1189518                       NaN               NaN     NaN
# 1234381                       NaN               NaN     NaN
# 1235584                       NaN               NaN     NaN
# 1279161                       NaN               NaN     NaN
#
# [13 rows x 48 columns]
