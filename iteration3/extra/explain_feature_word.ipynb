# %%
import numpy as np
import pandas as pd

WORKING_DIRECTORY = '/mnt/c/git/masters-thesis-code/jupyter/code/'

COMPANIES_DF = pd \
        .read_csv(WORKING_DIRECTORY + 'data/prod_data_companies_more_data_2021_09_16.csv',
                  delimiter='\t',
                  na_values='(null)',
                  dtype={
                      'business_id': str,
                      'business_id_start_date': str,
                      'company_name': str,
                      'email_address': str,
                      'industry_code': str,
                      'language': str,
                      'company_form': str,
                      'company_form_code': str,
                      'domicile_code': str,
                      'region_code': str,
                      'location_municipality_code': str,
                      'location_region_code': str,
                      'company_status_code': str,
                      'balance_industry_code': str,
                      'personnel_class': str,
                      'turnover_class': str,
                      'statement_date': str,
                      'statement_length': float,
                      'target_year': str,
                      'turnover': float,
                      'raw_materials_use': float,
                      'current_ratio': float,
                      'personnel_expenses': float,
                      'investment_expenses_cash_flow': float,
                      'ebitda': float,
                      'operating_profit_per_turnover': float,
                      'ebit': float,
                      'turnover_growth_percent': float,
                      'ebit_per_turnover': float,
                      'short_term_sales_receivable': float,
                      'net_profit': float,
                      'net_profit_per_turnover': float,
                      'aggregate_equity': float,
                      'return_on_equity_percent': float,
                      'equity_ratio': float,
                      'long_term_sales_receivable': float,
                      'quick_ratio': float,
                      'buildings': float,
                      'return_on_investment_percent': float,
                      'total_assets': float,
                      'external_services': float,
                      'aggregate_current_assets': float,
                      'personnel_average': float,
                      'concern': str,
                      'bulk': str,
                      'performer_ranking_points': float,
                      'risk_rating_class': str,
                      'latest': str
                  }
                  )

COMPANIES_DF.head()

# %%
COMPANIES_DF.sort_values('turnover', ascending=False)
# Out:
#         business_id business_id_start_date                     company_name  \
# 1244960    14636114             1998-04-27                       Fortum Oyj
# 379513     01120389             1978-03-15                        Nokia Oyj
# 479236     20584306             2006-09-07  Nokia Solutions and Networks Oy
# 780469     18523029             2003-09-17                        Neste Oyj
# 487063     01098628             1978-03-15                        Kesko Oyj
# ...             ...                    ...                              ...
# 1337857    21145030             2007-05-07          Tmi Markku Vuorentausta
# 1337859    24318670             2011-09-23                   Rabbit Hole Oy
# 1337865    30137091             2019-07-19        We Build Parks Finland Oy
# 1337866    32150097             2021-05-31              Orankien Osuuskunta
# 1337867    08445602             1991-06-05                 Ykkösmestarit Ky
#
#         email_address industry_code language  \
# 1244960           NaN         70100     CL_1
# 379513            NaN         70100     CL_1
# 479236            NaN         26200     CL_1
# 780469            NaN         19200     CL_1
# 487063            NaN         46901     CL_1
# ...               ...           ...      ...
# 1337857           NaN         47210     CL_1
# 1337859           NaN         85599     CL_1
# 1337865           NaN         42999     CL_1
# 1337866           NaN         62010     CL_1
# 1337867           NaN         95230     CL_1
#
#                              company_form company_form_code domicile_code  \
# 1244960               Julkinen osakeyhtiö             CO_17           049
# 379513                Julkinen osakeyhtiö             CO_17           091
# 479236                         Osakeyhtiö             CO_16           091
# 780469                Julkinen osakeyhtiö             CO_17           049
# 487063                Julkinen osakeyhtiö             CO_17           091
# ...                                   ...               ...           ...
# 1337857  Yksityinen elinkeinonharjoittaja             CO_26           638
# 1337859                        Osakeyhtiö             CO_16           091
# 1337865                        Osakeyhtiö             CO_16           261
# 1337866                        Osuuskunta             CO_14           091
# 1337867                 Kommandiittiyhtiö             CO_13           491
#
#         region_code  ... return_on_investment_percent  total_assets  \
# 1244960       RE_01  ...                          9.2  5.780900e+10
# 379513        RE_01  ...                         11.5  3.628500e+10
# 479236        RE_01  ...                         -1.1  1.894700e+10
# 780469        RE_01  ...                         19.6  9.814000e+09
# 487063        RE_01  ...                         11.6  6.641900e+09
# ...             ...  ...                          ...           ...
# 1337857       RE_01  ...                          NaN           NaN
# 1337859       RE_01  ...                          NaN  2.000000e+03
# 1337865       RE_19  ...                          NaN           NaN
# 1337866       RE_01  ...                          NaN           NaN
# 1337867       RE_10  ...                          NaN           NaN
#
#         external_services aggregate_current_assets personnel_average concern  \
# 1244960       389000000.0             1.395000e+09           19933.0    true
# 379513                NaN             2.248000e+09           92039.0    true
# 479236                NaN             7.135000e+08            5704.0   false
# 780469         72000000.0             1.829000e+09            4833.0    true
# 487063        189200000.0             8.369000e+08           17629.0    true
# ...                   ...                      ...               ...     ...
# 1337857               NaN                      NaN               NaN     NaN
# 1337859               NaN                      NaN               NaN   false
# 1337865               NaN                      NaN               NaN     NaN
# 1337866               NaN                      NaN               NaN     NaN
# 1337867               NaN                      NaN               NaN     NaN
#
#           bulk  performer_ranking_points risk_rating_class  latest
# 1244960  false                      53.0         GREEN_AAA    true
# 379513   false                      46.0           GREEN_A    true
# 479236   false                      33.0          YELLOW_B    true
# 780469   false                      67.0          GREEN_AA    true
# 487063   false                      39.0           GREEN_A    true
# ...        ...                       ...               ...     ...
# 1337857    NaN                       NaN               NaN     NaN
# 1337859   true                       NaN               NaN    true
# 1337865    NaN                       NaN               NaN     NaN
# 1337866    NaN                       NaN               NaN     NaN
# 1337867    NaN                       NaN               NaN     NaN
#
# [1337868 rows x 48 columns]

# %%
def find_rows_with_word(word):
    col_name, actual_word = word.split('+')
    print(col_name)
    print(actual_word)
    return COMPANIES_DF[COMPANIES_DF[col_name] == actual_word]

# %%
find_rows_with_word('company_form_code+CO_16')
