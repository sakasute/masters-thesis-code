# %% [markdown]
# # Tutkitaan avainsanojen esiintyvyyttä/erottelukykyä

# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# ## Ladataan yritysdata ja vuorovaikutusdata

# %%
SELECTED_COMPANY_FEATURES = ['company_form_code', 'location_municipality_code', 
                             'location_region_code', 'company_status_code', 'industry_code', 'turnover', 
                             'net_profit', 'personnel_average', 'performer_ranking_points', 'risk_rating_class']

# %%
COMPANIES = pd.read_pickle("data/pandas_pickles/prod_data_proto2.pkl")

# %%
ITEM_IDS = list(COMPANIES['business_id'].unique())
ITEM_IDS
# Out:
# ['31431209',
#  '32087307',
#  '18601103',
#  '20469041',
#  '24844507',
#  '01015810',
#  '01119927',
#  '02357927',
#  '02488679',
#  '05075714',
#  '06460411',
#  '07574322',
#  '08764347',
#  '09708355',
#  '10117341',
#  '10299456',
#  '10415357',
#  '14961099',
#  '16149387',
#  '17235578',
#  '17849078',
#  '20218672',
#  '19495891',
#  '21972159',
#  '21518909',
#  '20907849',
#  '23612800',
#  '23087997',
#  '22887116',
#  '22430888',
#  '24876568',
#  '24235437',
#  '23992604',
#  '24017691',
#  '27232477',
#  '29193547',
#  '29213405',
#  '28746293',
#  '28758024',
#  '28578007',
#  '31019003',
#  '31352025',
#  '01029964',
#  '01197028',
#  '04225637',
#  '05163087',
#  '04979017',
#  '04804735',
#  '08237512',
#  '08140892',
#  '08727546',
#  '08956429',
#  '10456837',
#  '14086095',
#  '13980124',
#  '14284040',
#  '14146588',
#  '28694323',
#  '14676984',
#  '14776563',
#  '15080621',
#  '15662840',
#  '17406496',
#  '18116781',
#  '18477018',
#  '19516832',
#  '19384278',
#  '22217884',
#  '21787615',
#  '22798535',
#  '23089474',
#  '25586028',
#  '25535511',
#  '25410145',
#  '25082276',
#  '24854318',
#  '24809509',
#  '24391907',
#  '24256369',
#  '26617869',
#  '26662547',
#  '26640217',
#  '26813288',
#  '26302875',
#  '25891073',
#  '29217238',
#  '28833653',
#  '28713117',
#  '28470995',
#  '31177589',
#  '31095276',
#  '29431824',
#  '11300383',
#  '32301844',
#  '31792901',
#  '07451568',
#  '08027240',
#  '08902156',
#  '10478518',
#  '11516555',
#  '13147749',
#  '16263892',
#  '17044181',
#  '17228722',
#  '18169170',
#  '18468197',
#  '20196960',
#  '20312415',
#  '20108596',
#  '20722529',
#  '23927677',
#  '22573467',
#  '25252693',
#  '25163308',
#  '27150842',
#  '26932586',
#  '26848173',
#  '26269489',
#  '26054226',
#  '01272649',
#  '01375066',
#  '02871344',
#  '06431151',
#  '08615894',
#  '10057772',
#  '09906677',
#  '12742693',
#  '14384295',
#  '14856731',
#  '22990586',
#  '17683928',
#  '18743849',
#  '20268581',
#  '19709669',
#  '23362071',
#  '22796329',
#  '23061607',
#  '22723867',
#  '22727833',
#  '22484085',
#  '25604935',
#  '24778060',
#  '24861067',
#  '25159923',
#  '24718711',
#  '24110378',
#  '27102234',
#  '26397974',
#  '26238017',
#  '25724814',
#  '25964586',
#  '25663062',
#  '28921514',
#  '29196932',
#  '29274953',
#  '28878755',
#  '28759254',
#  '28410159',
#  '27117591',
#  '26321961',
#  '25774256',
#  '25775654',
#  '25832276',
#  '29122757',
#  '28548318',
#  '28098062',
#  '28397791',
#  '28402896',
#  '27587411',
#  '27598292',
#  '27631507',
#  '27812607',
#  '31299746',
#  '31096551',
#  '29859927',
#  '32033093',
#  '32214636',
#  '31534339',
#  '31791204',
#  '31825902',
#  '25479417',
#  '12166526',
#  '13514318',
#  '29508721',
#  '01557804',
#  '02240972',
#  '03706682',
#  '05764851',
#  '08833429',
#  '09277225',
#  '13122947',
#  '13615733',
#  '13616920',
#  '13869768',
#  '14530926',
#  '14479155',
#  '15224875',
#  '16479917',
#  '16422531',
#  '18079853',
#  '20600126',
#  '20533234',
#  '21659306',
#  '21735786',
#  '21812307',
#  '21673351',
#  '21724737',
#  '21227677',
#  '21102495',
#  '21058412',
#  '23869868',
#  '23054730',
#  '23144955',
#  '25334189',
#  '25122768',
#  '26992124',
#  '26250702',
#  ...]

# %%
interactions_tmp = pd \
    .read_csv('data/interactions_2021_08_19.csv',
             delimiter='\t',
             dtype={
                 'group_id': 'string',
                 'business_id': 'string',
                 'owner': 'string'
             })

# Poistetaan vuorovaikutusdatasta sellaiset y-tunnukset, joita ei löydy kohteista
INTERACTIONS = interactions_tmp[interactions_tmp.business_id.isin(ITEM_IDS)]

print(interactions_tmp.shape)
print(INTERACTIONS.shape)
# Out:
# (548198, 3)
# (525513, 3)

# %%
features_tmp = [COMPANIES[feature].unique() for feature in SELECTED_COMPANY_FEATURES]
FEATURES = [item for sublist in features_tmp for item in sublist]
len(FEATURES)
FEATURES
# Out:
# ['company_form_code+CO_26',
#  'company_form_code+CO_16',
#  'company_form_code+CO_53',
#  'company_form_code+CO_2',
#  'company_form_code+CO_10',
#  'company_form_code+CO_13',
#  'company_form_code+CO_19',
#  'company_form_code+CO_5',
#  'company_form_code+CO_14',
#  'company_form_code+CO_6',
#  'company_form_code+CO_63',
#  'company_form_code+CO_51',
#  'company_form_code+CO_56',
#  'company_form_code+CO_60',
#  'company_form_code+CO_17',
#  'company_form_code+CO_0',
#  'company_form_code+CO_54',
#  'company_form_code+CO_18',
#  'company_form_code+CO_52',
#  'company_form_code+CO_50',
#  'company_form_code+CO_57',
#  'company_form_code+CO_31',
#  'company_form_code+CO_29',
#  'company_form_code+CO_41',
#  'company_form_code+CO_71',
#  'company_form_code+CO_39',
#  'company_form_code+CO_36',
#  'company_form_code+CO_90',
#  'company_form_code+CO_48',
#  'company_form_code+CO_44',
#  'company_form_code+CO_59',
#  'company_form_code+CO_55',
#  'company_form_code+CO_42',
#  'company_form_code+CO_40',
#  'company_form_code+CO_15',
#  'company_form_code+CO_70',
#  'company_form_code+CO_58',
#  'company_form_code+CO_32',
#  'company_form_code+CO_46',
#  'company_form_code+CO_43',
#  'company_form_code+CO_47',
#  'company_form_code+CO_12',
#  'company_form_code+CO_24',
#  'company_form_code+CO_38',
#  'company_form_code+CO_49',
#  'company_form_code+CO_37',
#  'company_form_code+CO_4',
#  'company_form_code+CO_30',
#  'company_form_code+CO_21',
#  'company_form_code+CO_45',
#  'company_form_code+CO_22',
#  'company_form_code+CO_28',
#  'company_form_code+CO_9',
#  'company_form_code+CO_1',
#  'company_form_code+CO_35',
#  'company_form_code+CO_25',
#  'company_form_code+CO_3',
#  'company_form_code+CO_33',
#  'company_form_code+CO_20',
#  'company_form_code+CO_8',
#  'company_form_code+CO_7',
#  'company_form_code+NaN',
#  'company_form_code+CO_80',
#  'company_form_code+CO_61',
#  'company_form_code+CO_23',
#  'location_municipality_code+091',
#  'location_municipality_code+NaN',
#  'location_municipality_code+049',
#  'location_municipality_code+272',
#  'location_municipality_code+636',
#  'location_municipality_code+535',
#  'location_municipality_code+297',
#  'location_municipality_code+837',
#  'location_municipality_code+504',
#  'location_municipality_code+853',
#  'location_municipality_code+016',
#  'location_municipality_code+405',
#  'location_municipality_code+564',
#  'location_municipality_code+092',
#  'location_municipality_code+186',
#  'location_municipality_code+980',
#  'location_municipality_code+859',
#  'location_municipality_code+707',
#  'location_municipality_code+499',
#  'location_municipality_code+545',
#  'location_municipality_code+743',
#  'location_municipality_code+005',
#  'location_municipality_code+678',
#  'location_municipality_code+758',
#  'location_municipality_code+402',
#  'location_municipality_code+753',
#  'location_municipality_code+179',
#  'location_municipality_code+244',
#  'location_municipality_code+410',
#  'location_municipality_code+536',
#  'location_municipality_code+245',
#  'location_municipality_code+286',
#  'location_municipality_code+061',
#  'location_municipality_code+505',
#  'location_municipality_code+430',
#  'location_municipality_code+109',
#  'location_municipality_code+398',
#  'location_municipality_code+018',
#  'location_municipality_code+436',
#  'location_municipality_code+740',
#  'location_municipality_code+858',
#  'location_municipality_code+927',
#  'location_municipality_code+563',
#  'location_municipality_code+620',
#  'location_municipality_code+895',
#  'location_municipality_code+508',
#  'location_municipality_code+765',
#  'location_municipality_code+844',
#  'location_municipality_code+106',
#  'location_municipality_code+851',
#  'location_municipality_code+905',
#  'location_municipality_code+759',
#  'location_municipality_code+235',
#  'location_municipality_code+543',
#  'location_municipality_code+202',
#  'location_municipality_code+749',
#  'location_municipality_code+478',
#  'location_municipality_code+680',
#  'location_municipality_code+285',
#  'location_municipality_code+781',
#  'location_municipality_code+734',
#  'location_municipality_code+925',
#  'location_municipality_code+494',
#  'location_municipality_code+915',
#  'location_municipality_code+694',
#  'location_municipality_code+075',
#  'location_municipality_code+908',
#  'location_municipality_code+165',
#  'location_municipality_code+213',
#  'location_municipality_code+681',
#  'location_municipality_code+224',
#  'location_municipality_code+140',
#  'location_municipality_code+702',
#  'location_municipality_code+710',
#  'location_municipality_code+211',
#  'location_municipality_code+791',
#  'location_municipality_code+261',
#  'location_municipality_code+638',
#  'location_municipality_code+440',
#  'location_municipality_code+176',
#  'location_municipality_code+273',
#  'location_municipality_code+169',
#  'location_municipality_code+698',
#  'location_municipality_code+182',
#  'location_municipality_code+263',
#  'location_municipality_code+233',
#  'location_municipality_code+108',
#  'location_municipality_code+615',
#  'location_municipality_code+167',
#  'location_municipality_code+418',
#  'location_municipality_code+204',
#  'location_municipality_code+205',
#  'location_municipality_code+748',
#  'location_municipality_code+609',
#  'location_municipality_code+577',
#  'location_municipality_code+170',
#  'location_municipality_code+500',
#  'location_municipality_code+232',
#  'location_municipality_code+098',
#  'location_municipality_code+444',
#  'location_municipality_code+593',
#  'location_municipality_code+529',
#  'location_municipality_code+778',
#  'location_municipality_code+491',
#  'location_municipality_code+616',
#  'location_municipality_code+924',
#  'location_municipality_code+738',
#  'location_municipality_code+153',
#  'location_municipality_code+051',
#  'location_municipality_code+495',
#  'location_municipality_code+399',
#  'location_municipality_code+684',
#  'location_municipality_code+423',
#  'location_municipality_code+561',
#  'location_municipality_code+260',
#  'location_municipality_code+831',
#  'location_municipality_code+790',
#  'location_municipality_code+214',
#  'location_municipality_code+611',
#  'location_municipality_code+218',
#  'location_municipality_code+241',
#  'location_municipality_code+777',
#  'location_municipality_code+601',
#  'location_municipality_code+977',
#  'location_municipality_code+433',
#  'location_municipality_code+562',
#  'location_municipality_code+434',
#  'location_municipality_code+305',
#  'location_municipality_code+408',
#  'location_municipality_code+976',
#  'location_municipality_code+560',
#  'location_municipality_code+890',
#  'location_municipality_code+435',
#  'location_municipality_code+047',
#  'location_municipality_code+541',
#  'location_municipality_code+145',
#  'location_municipality_code+078',
#  'location_municipality_code+271',
#  'location_municipality_code+322',
#  'location_municipality_code+149',
#  'location_municipality_code+946',
#  'location_municipality_code+992',
#  'location_municipality_code+240',
#  'location_municipality_code+941',
#  'location_municipality_code+079',
#  'location_municipality_code+592',
#  'location_municipality_code+635',
#  'location_municipality_code+257',
#  'location_municipality_code+226',
#  'location_municipality_code+102',
#  'location_municipality_code+886',
#  'location_municipality_code+146',
#  'location_municipality_code+400',
#  'location_municipality_code+892',
#  'location_municipality_code+531',
#  'location_municipality_code+761',
#  'location_municipality_code+426',
#  'location_municipality_code+584',
#  'location_municipality_code+276',
#  'location_municipality_code+507',
#  'location_municipality_code+111',
#  'location_municipality_code+689',
#  'location_municipality_code+256',
#  'location_municipality_code+484',
#  'location_municipality_code+143',
#  'location_municipality_code+475',
#  'location_municipality_code+686',
#  'location_municipality_code+445',
#  'location_municipality_code+887',
#  'location_municipality_code+704',
#  'location_municipality_code+086',
#  'location_municipality_code+250',
#  'location_municipality_code+598',
#  'location_municipality_code+069',
#  'location_municipality_code+090',
#  'location_municipality_code+607',
#  'location_municipality_code+236',
#  'location_municipality_code+291',
#  'location_municipality_code+834',
#  'location_municipality_code+425',
#  'location_municipality_code+148',
#  'location_municipality_code+301',
#  'location_municipality_code+619',
#  'location_municipality_code+503',
#  'location_municipality_code+422',
#  'location_municipality_code+249',
#  'location_municipality_code+989',
#  'location_municipality_code+217',
#  'location_municipality_code+700',
#  'location_municipality_code+729',
#  'location_municipality_code+481',
#  'location_municipality_code+178',
#  'location_municipality_code+172',
#  'location_municipality_code+081',
#  'location_municipality_code+889',
#  'location_municipality_code+151',
#  'location_municipality_code+312',
#  'location_municipality_code+071',
#  'location_municipality_code+604',
#  'location_municipality_code+139',
#  'location_municipality_code+498',
#  'location_municipality_code+420',
#  'location_municipality_code+020',
#  'location_municipality_code+050',
#  'location_municipality_code+317',
#  'location_municipality_code+077',
#  'location_municipality_code+783',
#  'location_municipality_code+846',
#  'location_municipality_code+316',
#  'location_municipality_code+936',
#  'location_municipality_code+082',
#  'location_municipality_code+538',
#  'location_municipality_code+035',
#  'location_municipality_code+290',
#  'location_municipality_code+309',
#  'location_municipality_code+683',
#  'location_municipality_code+320',
#  'location_municipality_code+595',
#  'location_municipality_code+608',
#  'location_municipality_code+171',
#  'location_municipality_code+280',
#  'location_municipality_code+441',
#  'location_municipality_code+691',
#  'location_municipality_code+480',
#  'location_municipality_code+580',
#  'location_municipality_code+931',
#  'location_municipality_code+052',
#  'location_municipality_code+208',
#  'location_municipality_code+287',
#  'location_municipality_code+288',
#  'location_municipality_code+755',
#  'location_municipality_code+849',
#  'location_municipality_code+751',
#  'location_municipality_code+934',
#  'location_municipality_code+626',
#  'location_municipality_code+181',
#  'location_municipality_code+599',
#  'location_municipality_code+581',
#  'location_municipality_code+762',
#  'location_municipality_code+588',
#  'location_municipality_code+768',
#  'location_municipality_code+152',
#  'location_municipality_code+060',
#  'location_municipality_code+417',
#  'location_municipality_code+893',
#  'location_municipality_code+142',
#  'location_municipality_code+832',
#  'location_municipality_code+230',
#  'location_municipality_code+747',
#  'location_municipality_code+732',
#  'location_municipality_code+631',
#  'location_municipality_code+010',
#  'location_municipality_code+845',
#  'location_municipality_code+583',
#  'location_municipality_code+576',
#  'location_municipality_code+578',
#  'location_municipality_code+304',
#  'location_municipality_code+687',
#  'location_municipality_code+043',
#  'location_municipality_code+746',
#  'location_municipality_code+742',
#  'location_municipality_code+483',
#  'location_municipality_code+009',
#  'location_municipality_code+850',
#  'location_municipality_code+239',
#  'location_municipality_code+097',
#  'location_municipality_code+624',
#  'location_municipality_code+785',
#  'location_municipality_code+318',
#  'location_municipality_code+076',
#  'location_municipality_code+848',
#  'location_municipality_code+739',
#  'location_municipality_code+771',
#  'location_municipality_code+614',
#  'location_municipality_code+275',
#  'location_municipality_code+922',
#  'location_municipality_code+103',
#  'location_municipality_code+981',
#  'location_municipality_code+265',
#  'location_municipality_code+019',
#  'location_municipality_code+403',
#  'location_municipality_code+854',
#  'location_municipality_code+623',
#  'location_municipality_code+630',
#  'location_municipality_code+625',
#  'location_municipality_code+231',
#  'location_municipality_code+918',
#  'location_municipality_code+062',
#  'location_municipality_code+416',
#  'location_municipality_code+074',
#  'location_municipality_code+300',
#  'location_municipality_code+407',
#  'location_municipality_code+935',
#  'location_municipality_code+736',
#  'location_municipality_code+072',
#  'location_municipality_code+105',
#  'location_municipality_code+833',
#  'location_municipality_code+216',
#  'location_municipality_code+857',
#  'location_municipality_code+284',
#  'location_municipality_code+489',
#  'location_municipality_code+438',
#  'location_municipality_code+921',
#  'location_municipality_code+421',
#  'location_municipality_code+065',
#  'location_municipality_code+177',
#  'location_municipality_code+295',
#  'location_municipality_code+046',
#  'location_municipality_code+766',
#  'location_municipality_code+697',
#  'location_region_code+01',
#  'location_region_code+NaN',
#  'location_region_code+16',
#  'location_region_code+02',
#  'location_region_code+17',
#  'location_region_code+11',
#  'location_region_code+06',
#  'location_region_code+07',
#  'location_region_code+09',
#  'location_region_code+12',
#  'location_region_code+15',
#  'location_region_code+14',
#  'location_region_code+19',
#  'location_region_code+13',
#  'location_region_code+08',
#  'location_region_code+05',
#  'location_region_code+10',
#  'location_region_code+18',
#  'location_region_code+21',
#  'location_region_code+04',
#  'company_status_code+AKT',
#  'company_status_code+SELTILA',
#  'company_status_code+KESK',
#  'company_status_code+KONK',
#  'company_status_code+SANE',
#  'industry_code+43',
#  'industry_code+68',
#  'industry_code+74',
#  'industry_code+NaN',
#  'industry_code+49',
#  'industry_code+01',
#  'industry_code+46',
#  'industry_code+90',
#  'industry_code+86',
#  'industry_code+56',
#  'industry_code+79',
#  'industry_code+41',
#  'industry_code+62',
#  'industry_code+87',
#  'industry_code+93',
#  'industry_code+81',
#  'industry_code+47',
#  'industry_code+22',
#  'industry_code+33',
#  'industry_code+71',
#  'industry_code+85',
#  'industry_code+45',
#  'industry_code+69',
#  'industry_code+18',
#  'industry_code+31',
#  'industry_code+25',
#  'industry_code+02',
#  'industry_code+59',
#  'industry_code+66',
#  'industry_code+70',
#  'industry_code+64',
#  'industry_code+10',
#  'industry_code+88',
#  'industry_code+14',
#  'industry_code+82',
#  'industry_code+55',
#  'industry_code+52',
#  'industry_code+96',
#  'industry_code+73',
#  'industry_code+77',
#  'industry_code+28',
#  'industry_code+61',
#  'industry_code+95',
#  'industry_code+80',
#  'industry_code+13',
#  'industry_code+63',
#  'industry_code+16',
#  'industry_code+03',
#  'industry_code+42',
#  'industry_code+17',
#  'industry_code+32',
#  'industry_code+26',
#  'industry_code+35',
#  'industry_code+08',
#  'industry_code+75',
#  'industry_code+36',
#  'industry_code+78',
#  'industry_code+53',
#  'industry_code+00',
#  'industry_code+94',
#  'industry_code+23',
#  'industry_code+27',
#  'industry_code+72',
#  'industry_code+38',
#  'industry_code+58',
#  'industry_code+20',
#  'industry_code+29',
#  'industry_code+37',
#  'industry_code+65',
#  'industry_code+30',
#  'industry_code+50',
#  'industry_code+84',
#  'industry_code+91',
#  'industry_code+99',
#  'industry_code+11',
#  'industry_code+21',
#  'industry_code+15',
#  'industry_code+60',
#  'industry_code+24',
#  'industry_code+09',
#  'industry_code+51',
#  'industry_code+39',
#  'industry_code+07',
#  'industry_code+97',
#  'industry_code+92',
#  'industry_code+19',
#  'industry_code+98',
#  'industry_code+06',
#  'industry_code+12',
#  'industry_code+05',
#  'turnover+NaN',
#  'turnover+0.4',
#  'turnover+0.98',
#  'turnover+0.2',
#  'turnover+0.8',
#  'turnover+0.9',
#  'turnover+0.6',
#  'turnover+top',
#  'turnover+0.99',
#  'net_profit+NaN',
#  'net_profit+0.8',
#  'net_profit+0.2',
#  'net_profit+0.6',
#  'net_profit+0.9',
#  'net_profit+0.98',
#  'net_profit+0.4',
#  'net_profit+0.99',
#  'net_profit+top',
#  'personnel_average+NaN',
#  'personnel_average+0.4',
#  'personnel_average+0.9',
#  'personnel_average+0.8',
#  'personnel_average+0.6',
#  'personnel_average+0.2',
#  'personnel_average+0.98',
#  'personnel_average+0.99',
#  'personnel_average+top',
#  'performer_ranking_points+NaN',
#  'performer_ranking_points+0.9',
#  'performer_ranking_points+0.4',
#  'performer_ranking_points+0.98',
#  'performer_ranking_points+0.6',
#  'performer_ranking_points+0.8',
#  'performer_ranking_points+0.2',
#  'performer_ranking_points+top',
#  'performer_ranking_points+0.99',
#  'risk_rating_class+NaN',
#  'risk_rating_class+GREEN',
#  'risk_rating_class+YELLOW',
#  'risk_rating_class+RED']

# %% [markdown]
# ## Luodaan yritys/feature-matriisi Gini-indeksin laskemista varten

# %%
def calculate_gini_for_word(word):
    col_name = word.split('+')[0]
    matches_df = COMPANIES[COMPANIES[col_name] == word]
    
    matched_docs_total = matches_df.shape[0]
    print(matched_docs_total)    
    
    match_bids = list(matches_df['business_id'].unique())
    
    matching_interactions_df = INTERACTIONS[INTERACTIONS['business_id'].isin(match_bids)]
    
    interacted_docs_count = matching_interactions_df['business_id'].unique().shape[0]
    non_interacted_docs_count = matched_docs_total - interacted_docs_count
    
    gini_index = 1 - ((interacted_docs_count / matched_docs_total) ** 2 + \
                    (non_interacted_docs_count / matched_docs_total) ** 2)
    
    
    print(interacted_docs_count)
    
    return gini_index

# %%
print(calculate_gini_for_word('location_municipality_code+NaN'))
# Out:
# 888180
# 39115
# 0.08420003849323976

# %%
COMPANIES[COMPANIES['risk_rating_class'] == 'risk_rating_class+RED']

# %%
GINI_SCORES = []

for word in FEATURES:
    gini = calculate_gini_for_word(word)
    GINI_SCORES.append((word, gini))

# %%
GINI_DF = pd.DataFrame(GINI_SCORES, columns=['feature', 'gini_score'])

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(GINI_DF.sort_values('gini_score'))
# Out:
#                             feature  gini_score
# 58          company_form_code+CO_20    0.000000
# 54          company_form_code+CO_35    0.000000
# 43          company_form_code+CO_38    0.000000
# 59           company_form_code+CO_8    0.000000
# 53           company_form_code+CO_1    0.000000
# 52           company_form_code+CO_9    0.000000
# 515          personnel_average+0.99    0.000000
# 51          company_form_code+CO_28    0.000000
# 15           company_form_code+CO_0    0.000000
# 60           company_form_code+CO_7    0.000000
# 27          company_form_code+CO_90    0.000000
# 483                industry_code+97    0.000000
# 48          company_form_code+CO_21    0.000000
# 61            company_form_code+NaN    0.000000
# 516           personnel_average+top    0.000000
# 489                industry_code+05    0.000000
# 63          company_form_code+CO_61    0.000000
# 64          company_form_code+CO_23    0.000000
# 488                industry_code+12    0.000000
# 487                industry_code+06    0.000000
# 36          company_form_code+CO_58    0.000000
# 56           company_form_code+CO_3    0.000000
# 2           company_form_code+CO_53    0.002522
# 403               industry_code+NaN    0.002790
# 3            company_form_code+CO_2    0.005857
# 498                   turnover+0.99    0.007034
# 497                    turnover+top    0.008197
# 31          company_form_code+CO_55    0.009740
# 11          company_form_code+CO_51    0.010182
# 16          company_form_code+CO_54    0.011027
# 24          company_form_code+CO_71    0.011560
# 19          company_form_code+CO_50    0.012650
# 10          company_form_code+CO_63    0.014582
# 18          company_form_code+CO_52    0.014759
# 12          company_form_code+CO_56    0.017803
# 426                industry_code+02    0.021447
# 458                industry_code+00    0.022997
# 23          company_form_code+CO_41    0.025153
# 514          personnel_average+0.98    0.027459
# 22          company_form_code+CO_29    0.030347
# 14          company_form_code+CO_17    0.030880
# 405                industry_code+01    0.035496
# 447                industry_code+03    0.038071
# 0           company_form_code+CO_26    0.040645
# 38          company_form_code+CO_46    0.043457
# 20          company_form_code+CO_57    0.046796
# 499                  net_profit+NaN    0.051239
# 289  location_municipality_code+580    0.051510
# 13          company_form_code+CO_60    0.054727
# 492                   turnover+0.98    0.057354
# 486                industry_code+98    0.060547
# 30          company_form_code+CO_59    0.061288
# 4           company_form_code+CO_10    0.062770
# 490                    turnover+NaN    0.070859
# 286  location_municipality_code+441    0.072536
# 407                industry_code+90    0.074270
# 21          company_form_code+CO_31    0.077930
# 9            company_form_code+CO_6    0.083351
# 66   location_municipality_code+NaN    0.084200
# 517    performer_ranking_points+NaN    0.084386
# 376        location_region_code+NaN    0.084585
# 526           risk_rating_class+NaN    0.090713
# 401                industry_code+68    0.091090
# 507                  net_profit+top    0.093537
# 510           personnel_average+0.9    0.099180
# 474                industry_code+11    0.102847
# 457                industry_code+53    0.104567
# 353  location_municipality_code+416    0.107037
# 41          company_form_code+CO_12    0.117188
# 437                industry_code+96    0.118910
# 431                industry_code+10    0.129365
# 397        company_status_code+KESK    0.134257
# 508           personnel_average+NaN    0.139478
# 473                industry_code+99    0.139551
# 373  location_municipality_code+766    0.142012
# 34          company_form_code+CO_15    0.145429
# 454                industry_code+75    0.146707
# 414                industry_code+93    0.155626
# 50          company_form_code+CO_22    0.165289
# 459                industry_code+94    0.166186
# 415                industry_code+81    0.167912
# 26          company_form_code+CO_36    0.168740
# 307  location_municipality_code+060    0.168740
# 506                 net_profit+0.99    0.170978
# 334  location_municipality_code+076    0.184830
# 285  location_municipality_code+280    0.186759
# 395         company_status_code+AKT    0.187399
# 7            company_form_code+CO_5    0.188716
# 511           personnel_average+0.8    0.191610
# 433                industry_code+14    0.193472
# 208  location_municipality_code+941    0.193762
# 369  location_municipality_code+065    0.197531
# 484                industry_code+92    0.197531
# 5           company_form_code+CO_13    0.197598
# 326  location_municipality_code+483    0.200312
# 362  location_municipality_code+216    0.209751
# 343  location_municipality_code+265    0.209751
# 358  location_municipality_code+736    0.211200
# 308  location_municipality_code+417    0.212247
# 197  location_municipality_code+435    0.214568
# 342  location_municipality_code+981    0.215858
# 47          company_form_code+CO_30    0.218750
# 149  location_municipality_code+263    0.221230
# 428                industry_code+66    0.221420
# 371  location_municipality_code+295    0.223537
# 332  location_municipality_code+785    0.224082
# 294  location_municipality_code+288    0.224599
# 438                industry_code+73    0.224741
# 233  location_municipality_code+887    0.225720
# 49          company_form_code+CO_45    0.226843
# 240  location_municipality_code+607    0.226843
# 277  location_municipality_code+035    0.227608
# 107  location_municipality_code+563    0.227673
# 297  location_municipality_code+751    0.227896
# 352  location_municipality_code+062    0.227896
# 374  location_municipality_code+697    0.228140
# 363  location_municipality_code+857    0.229557
# 432                industry_code+88    0.229625
# 143  location_municipality_code+440    0.230427
# 309  location_municipality_code+893    0.230700
# 410                industry_code+79    0.231474
# 434                industry_code+82    0.231671
# 301  location_municipality_code+599    0.231880
# 205  location_municipality_code+946    0.233156
# 313  location_municipality_code+747    0.234044
# 276  location_municipality_code+538    0.237965
# 393         location_region_code+21    0.239105
# 322  location_municipality_code+687    0.239855
# 402                industry_code+74    0.240274
# 325  location_municipality_code+742    0.240800
# 287  location_municipality_code+691    0.242757
# 442                industry_code+95    0.242991
# 89   location_municipality_code+402    0.243449
# 430                industry_code+64    0.243483
# 39          company_form_code+CO_43    0.244898
# 121  location_municipality_code+478    0.245704
# 360  location_municipality_code+105    0.247351
# 372  location_municipality_code+046    0.249463
# 299  location_municipality_code+626    0.250026
# 367  location_municipality_code+921    0.252737
# 476                industry_code+15    0.252838
# 495                    turnover+0.9    0.256139
# 340  location_municipality_code+922    0.256241
# 408                industry_code+86    0.257153
# 319  location_municipality_code+576    0.259577
# 329  location_municipality_code+239    0.259644
# 127  location_municipality_code+494    0.260158
# 55          company_form_code+CO_25    0.260355
# 157  location_municipality_code+748    0.260633
# 270  location_municipality_code+077    0.260690
# 84   location_municipality_code+545    0.260990
# 108  location_municipality_code+620    0.263210
# 160  location_municipality_code+170    0.263572
# 220  location_municipality_code+761    0.263868
# 230  location_municipality_code+475    0.264045
# 259  location_municipality_code+889    0.264266
# 236  location_municipality_code+250    0.264670
# 175  location_municipality_code+399    0.264697
# 349  location_municipality_code+625    0.265196
# 124  location_municipality_code+781    0.267716
# 144  location_municipality_code+176    0.270799
# 226  location_municipality_code+689    0.271731
# 444                industry_code+13    0.271834
# 186  location_municipality_code+777    0.272283
# 300  location_municipality_code+181    0.272391
# 249  location_municipality_code+422    0.272976
# 248  location_municipality_code+503    0.273386
# 83   location_municipality_code+499    0.273719
# 385         location_region_code+15    0.275293
# 337  location_municipality_code+771    0.275615
# 210  location_municipality_code+592    0.275937
# 174  location_municipality_code+495    0.276025
# 114  location_municipality_code+851    0.276129
# 203  location_municipality_code+322    0.276884
# 427                industry_code+59    0.277027
# 450                industry_code+32    0.277270
# 199  location_municipality_code+541    0.278435
# 468                industry_code+65    0.278707
# 228  location_municipality_code+484    0.279596
# 262  location_municipality_code+071    0.280897
# 196  location_municipality_code+890    0.280897
# 312  location_municipality_code+230    0.281264
# 273  location_municipality_code+316    0.281800
# 282  location_municipality_code+595    0.282849
# 296  location_municipality_code+849    0.282916
# 257  location_municipality_code+172    0.283352
# 227  location_municipality_code+256    0.283824
# 347  location_municipality_code+623    0.283908
# 187  location_municipality_code+601    0.283976
# 304  location_municipality_code+588    0.284082
# 323  location_municipality_code+043    0.284668
# 202  location_municipality_code+271    0.284912
# 327  location_municipality_code+009    0.285123
# 293  location_municipality_code+287    0.286015
# 237  location_municipality_code+598    0.287636
# 288  location_municipality_code+480    0.287994
# 81   location_municipality_code+859    0.288836
# 140  location_municipality_code+791    0.289425
# 281  location_municipality_code+320    0.289845
# 351  location_municipality_code+918    0.290384
# 134  location_municipality_code+681    0.290657
# 200  location_municipality_code+145    0.290738
# 247  location_municipality_code+619    0.290963
# 462                industry_code+72    0.291032
# 341  location_municipality_code+103    0.291121
# 315  location_municipality_code+631    0.291243
# 120  location_municipality_code+749    0.291340
# 69   location_municipality_code+636    0.291468
# 472                industry_code+91    0.291830
# 366  location_municipality_code+438    0.292346
# 392         location_region_code+18    0.292628
# 303  location_municipality_code+762    0.293177
# 103  location_municipality_code+436    0.293367
# 317  location_municipality_code+845    0.293702
# 184  location_municipality_code+218    0.294052
# 151  location_municipality_code+108    0.294248
# 245  location_municipality_code+148    0.295028
# 88   location_municipality_code+758    0.295124
# 235  location_municipality_code+086    0.295797
# 209  location_municipality_code+079    0.296522
# 244  location_municipality_code+425    0.296576
# 278  location_municipality_code+290    0.296714
# 115  location_municipality_code+905    0.297118
# 145  location_municipality_code+273    0.297317
# 320  location_municipality_code+578    0.297521
# 138  location_municipality_code+710    0.297945
# 229  location_municipality_code+143    0.297951
# 181  location_municipality_code+790    0.298465
# 130  location_municipality_code+075    0.298623
# 266  location_municipality_code+420    0.299018
# 155  location_municipality_code+204    0.299537
# 219  location_municipality_code+531    0.299608
# 215  location_municipality_code+886    0.299818
# 173  location_municipality_code+051    0.300503
# 111  location_municipality_code+765    0.301164
# 269  location_municipality_code+317    0.301341
# 265  location_municipality_code+498    0.301431
# 420                industry_code+85    0.302102
# 224  location_municipality_code+507    0.302140
# 504                 net_profit+0.98    0.302254
# 380         location_region_code+11    0.302662
# 339  location_municipality_code+275    0.302866
# 429                industry_code+70    0.302869
# 350  location_municipality_code+231    0.303361
# 310  location_municipality_code+142    0.303437
# 291  location_municipality_code+052    0.303774
# 231  location_municipality_code+686    0.304125
# 182  location_municipality_code+214    0.304411
# 75   location_municipality_code+016    0.304688
# 238  location_municipality_code+069    0.304839
# 346  location_municipality_code+854    0.304928
# 71   location_municipality_code+297    0.305044
# 87   location_municipality_code+678    0.305308
# 156  location_municipality_code+205    0.305567
# 214  location_municipality_code+102    0.306529
# 190  location_municipality_code+562    0.306556
# 131  location_municipality_code+908    0.306741
# 198  location_municipality_code+047    0.308102
# 254  location_municipality_code+729    0.308248
# 328  location_municipality_code+850    0.308390
# 268  location_municipality_code+050    0.308949
# 314  location_municipality_code+732    0.309194
# 195  location_municipality_code+560    0.309521
# 365  location_municipality_code+489    0.309642
# 137  location_municipality_code+702    0.310651
# 283  location_municipality_code+608    0.310945
# 148  location_municipality_code+182    0.311051
# 211  location_municipality_code+635    0.311144
# 232  location_municipality_code+445    0.311309
# 267  location_municipality_code+020    0.311327
# 355  location_municipality_code+300    0.311682
# 345  location_municipality_code+403    0.312331
# 387         location_region_code+19    0.312380
# 225  location_municipality_code+111    0.312643
# 206  location_municipality_code+992    0.313096
# 280  location_municipality_code+683    0.314007
# 216  location_municipality_code+146    0.314256
# 252  location_municipality_code+217    0.315046
# 125  location_municipality_code+734    0.315085
# 146  location_municipality_code+169    0.315329
# 256  location_municipality_code+178    0.315814
# 100  location_municipality_code+109    0.316052
# 331  location_municipality_code+624    0.316150
# 416                industry_code+47    0.316311
# 192  location_municipality_code+305    0.316677
# 250  location_municipality_code+249    0.316697
# 110  location_municipality_code+508    0.317162
# 162  location_municipality_code+232    0.317555
# 394         location_region_code+04    0.317604
# 344  location_municipality_code+019    0.318294
# 221  location_municipality_code+426    0.318380
# 271  location_municipality_code+783    0.319152
# 194  location_municipality_code+976    0.319252
# 389         location_region_code+08    0.319446
# 379         location_region_code+17    0.319889
# 152  location_municipality_code+615    0.320000
# 338  location_municipality_code+614    0.320000
# 129  location_municipality_code+694    0.320444
# 123  location_municipality_code+285    0.320849
# 141  location_municipality_code+261    0.320902
# 272  location_municipality_code+846    0.322170
# 243  location_municipality_code+834    0.322264
# 255  location_municipality_code+481    0.322564
# 188  location_municipality_code+977    0.322738
# 189  location_municipality_code+433    0.322804
# 382         location_region_code+07    0.323233
# 96   location_municipality_code+286    0.323505
# 207  location_municipality_code+240    0.324122
# 306  location_municipality_code+152    0.324328
# 356  location_municipality_code+407    0.324675
# 390         location_region_code+05    0.324945
# 158  location_municipality_code+609    0.325157
# 73   location_municipality_code+504    0.325413
# 218  location_municipality_code+892    0.325853
# 136  location_municipality_code+140    0.325893
# 398        company_status_code+KONK    0.326156
# 377         location_region_code+16    0.326243
# 112  location_municipality_code+844    0.326744
# 68   location_municipality_code+272    0.326920
# 204  location_municipality_code+149    0.327105
# 170  location_municipality_code+924    0.327801
# 126  location_municipality_code+925    0.328503
# 133  location_municipality_code+213    0.328761
# 147  location_municipality_code+698    0.328938
# 77   location_municipality_code+564    0.329167
# 253  location_municipality_code+700    0.329379
# 101  location_municipality_code+398    0.329643
# 311  location_municipality_code+832    0.329861
# 279  location_municipality_code+309    0.330307
# 213  location_municipality_code+226    0.330835
# 93   location_municipality_code+410    0.330990
# 165  location_municipality_code+593    0.331087
# 99   location_municipality_code+430    0.331439
# 384         location_region_code+12    0.332426
# 117  location_municipality_code+235    0.332746
# 168  location_municipality_code+491    0.332840
# 264  location_municipality_code+139    0.333453
# 284  location_municipality_code+171    0.333453
# 274  location_municipality_code+936    0.333888
# 260  location_municipality_code+151    0.333908
# 150  location_municipality_code+233    0.334424
# 404                industry_code+49    0.334436
# 201  location_municipality_code+078    0.334588
# 159  location_municipality_code+577    0.334845
# 370  location_municipality_code+177    0.334853
# 298  location_municipality_code+934    0.334883
# 316  location_municipality_code+010    0.335231
# 251  location_municipality_code+989    0.335241
# 388         location_region_code+13    0.335337
# 246  location_municipality_code+301    0.335910
# 456                industry_code+78    0.335918
# 391         location_region_code+10    0.336102
# 193  location_municipality_code+408    0.336125
# 116  location_municipality_code+759    0.336378
# 42          company_form_code+CO_24    0.336735
# 348  location_municipality_code+630    0.336735
# 167  location_municipality_code+778    0.337039
# 223  location_municipality_code+276    0.337377
# 241  location_municipality_code+236    0.337465
# 261  location_municipality_code+312    0.337611
# 70   location_municipality_code+535    0.337824
# 242  location_municipality_code+291    0.337831
# 381         location_region_code+06    0.337964
# 180  location_municipality_code+831    0.338331
# 94   location_municipality_code+536    0.338974
# 222  location_municipality_code+584    0.339612
# 72   location_municipality_code+837    0.339845
# 290  location_municipality_code+931    0.339984
# 217  location_municipality_code+400    0.339993
# 330  location_municipality_code+097    0.340265
# 378         location_region_code+02    0.340270
# 166  location_municipality_code+529    0.340470
# 212  location_municipality_code+257    0.340554
# 135  location_municipality_code+224    0.340564
# 132  location_municipality_code+165    0.340972
# 163  location_municipality_code+098    0.342466
# 364  location_municipality_code+284    0.342538
# 79   location_municipality_code+186    0.343142
# 321  location_municipality_code+304    0.343200
# 153  location_municipality_code+167    0.343804
# 128  location_municipality_code+915    0.344204
# 324  location_municipality_code+746    0.344523
# 302  location_municipality_code+581    0.347086
# 176  location_municipality_code+684    0.347386
# 368  location_municipality_code+421    0.347516
# 178  location_municipality_code+561    0.348188
# 422                industry_code+69    0.348375
# 275  location_municipality_code+082    0.348481
# 295  location_municipality_code+755    0.349066
# 336  location_municipality_code+739    0.349636
# 139  location_municipality_code+211    0.349922
# 122  location_municipality_code+680    0.350021
# 164  location_municipality_code+444    0.350246
# 239  location_municipality_code+090    0.350525
# 318  location_municipality_code+583    0.350823
# 80   location_municipality_code+980    0.351300
# 106  location_municipality_code+927    0.352087
# 292  location_municipality_code+208    0.352409
# 333  location_municipality_code+318    0.352653
# 91   location_municipality_code+179    0.352794
# 86   location_municipality_code+005    0.353452
# 74   location_municipality_code+853    0.353690
# 234  location_municipality_code+704    0.354514
# 191  location_municipality_code+434    0.355030
# 305  location_municipality_code+768    0.356157
# 113  location_municipality_code+106    0.357452
# 421                industry_code+45    0.357740
# 92   location_municipality_code+244    0.357968
# 109  location_municipality_code+895    0.360424
# 258  location_municipality_code+081    0.360561
# 185  location_municipality_code+241    0.361198
# 142  location_municipality_code+638    0.361368
# 102  location_municipality_code+018    0.361869
# 177  location_municipality_code+423    0.362739
# 470                industry_code+50    0.364044
# 169  location_municipality_code+616    0.364588
# 361  location_municipality_code+833    0.365032
# 448                industry_code+42    0.366221
# 104  location_municipality_code+740    0.366924
# 357  location_municipality_code+935    0.367065
# 354  location_municipality_code+074    0.367309
# 183  location_municipality_code+611    0.368286
# 411                industry_code+41    0.368369
# 97   location_municipality_code+061    0.370310
# 40          company_form_code+CO_47    0.370576
# 90   location_municipality_code+753    0.371000
# 386         location_region_code+14    0.373031
# 335  location_municipality_code+848    0.374230
# 512           personnel_average+0.6    0.375733
# 423                industry_code+18    0.379150
# 119  location_municipality_code+202    0.379447
# 82   location_municipality_code+707    0.379731
# 154  location_municipality_code+418    0.379843
# 172  location_municipality_code+153    0.380287
# 460                industry_code+23    0.380688
# 443                industry_code+80    0.382018
# 118  location_municipality_code+543    0.382192
# 445                industry_code+63    0.382203
# 76   location_municipality_code+405    0.382429
# 480                industry_code+51    0.385898
# 105  location_municipality_code+858    0.386244
# 67   location_municipality_code+049    0.387151
# 375         location_region_code+01    0.387360
# 98   location_municipality_code+505    0.387812
# 477                industry_code+60    0.387812
# 359  location_municipality_code+072    0.391833
# 29          company_form_code+CO_44    0.394907
# 179  location_municipality_code+260    0.396796
# 481                industry_code+39    0.399003
# 65   location_municipality_code+091    0.399390
# 161  location_municipality_code+500    0.400639
# 396     company_status_code+SELTILA    0.401144
# 78   location_municipality_code+092    0.401330
# 494                    turnover+0.8    0.407421
# 513           personnel_average+0.2    0.408163
# 171  location_municipality_code+738    0.412562
# 95   location_municipality_code+245    0.418488
# 525   performer_ranking_points+0.99    0.418634
# 435                industry_code+55    0.419799
# 35          company_form_code+CO_70    0.420000
# 452                industry_code+35    0.420540
# 524    performer_ranking_points+top    0.421034
# 400                industry_code+43    0.421569
# 439                industry_code+77    0.423771
# 469                industry_code+30    0.424615
# 503                  net_profit+0.9    0.425237
# 418                industry_code+33    0.427712
# 263  location_municipality_code+604    0.428378
# 436                industry_code+52    0.428978
# 493                    turnover+0.2    0.430338
# 419                industry_code+71    0.434124
# 406                industry_code+46    0.434415
# 32          company_form_code+CO_42    0.437190
# 399        company_status_code+SANE    0.437836
# 383         location_region_code+09    0.438259
# 85   location_municipality_code+743    0.439455
# 522    performer_ranking_points+0.8    0.440529
# 520   performer_ranking_points+0.98    0.440952
# 425                industry_code+25    0.442458
# 417                industry_code+22    0.444158
# 62          company_form_code+CO_80    0.444444
# 28          company_form_code+CO_48    0.444444
# 518    performer_ranking_points+0.9    0.445830
# 527         risk_rating_class+GREEN    0.445957
# 519    performer_ranking_points+0.4    0.450865
# 528        risk_rating_class+YELLOW    0.452197
# 424                industry_code+31    0.454436
# 502                  net_profit+0.6    0.454518
# 471                industry_code+84    0.455850
# 505                  net_profit+0.4    0.456178
# 412                industry_code+62    0.457855
# 446                industry_code+16    0.458743
# 521    performer_ranking_points+0.6    0.458911
# 8           company_form_code+CO_14    0.459950
# 451                industry_code+26    0.462088
# 25          company_form_code+CO_39    0.463571
# 529           risk_rating_class+RED    0.466161
# 523    performer_ranking_points+0.2    0.466309
# 461                industry_code+27    0.472188
# 479                industry_code+09    0.474311
# 44          company_form_code+CO_49    0.476371
# 453                industry_code+08    0.476522
# 440                industry_code+28    0.476949
# 33          company_form_code+CO_40    0.477502
# 466                industry_code+29    0.477779
# 491                    turnover+0.4    0.479105
# 57          company_form_code+CO_33    0.480000
# 46           company_form_code+CO_4    0.484429
# 17          company_form_code+CO_18    0.485646
# 1           company_form_code+CO_16    0.485668
# 37          company_form_code+CO_32    0.486111
# 475                industry_code+21    0.487535
# 409                industry_code+56    0.488587
# 467                industry_code+37    0.489451
# 501                  net_profit+0.2    0.492656
# 500                  net_profit+0.8    0.495050
# 6           company_form_code+CO_19    0.495144
# 464                industry_code+58    0.497212
# 496                    turnover+0.6    0.497222
# 465                industry_code+20    0.497449
# 455                industry_code+36    0.497539
# 509           personnel_average+0.4    0.498046
# 478                industry_code+24    0.498232
# 441                industry_code+61    0.498299
# 449                industry_code+17    0.499120
# 45          company_form_code+CO_37    0.499314
# 413                industry_code+87    0.499506
# 482                industry_code+07    0.499703
# 463                industry_code+38    0.499769
# 485                industry_code+19    0.500000

# %% [markdown]
# - Tätähän voi ehkä oikeesti käyttää "sanojen" valintaan!
#     - Esim. nähdään, että se "kiinnostaa" kuuluuko ylimpiin persentiileihin
#     - Lisäksi se "kiinnostaa" löytyykö jotain tietoa -> NaN luokat lähes järjestestään merkittävimpien sanojen joukossa
#
# - Gini-indeksissä kyllä vaarana se, että riittää, että jokin yritys on yhdessä ryhmässä, ja se nousee vuorovaikutettujen kohteiden joukkoon -> tietyt poiminnat voi nostaa selvästi joidenkin sanojen arvoa
#     - Kannattaa perehtyä johonkin muuhunkin metriikkaan
#
# - Jonkun rajan voisi määrittää, kuinka monta kertaa sanan pitää esiintyä, jotta se otetaan mukaan
